# %%
# Genearal usage
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
import scipy.stats as stats
import copy
import itertools
import math
import warnings

# model preparation and evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import KFold

# dimention reduction
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import accuracy_score, precision_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import silhouette_score

# LSTM
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import optuna

# %% [markdown]
# # 1. Problem 1

# %% [markdown]
# ## 1.2. PROPERLY SPLIT THE DATASET AND TRAIN YOUR MODEL. PRESENT THE TRAINING HISTORY AND EVALUATE ITS PERFORMANCE. (10 POINTS)

# %% [markdown]
# ### 1.2.1 Preprocessing

# %% [markdown]
# - Convert 'dteday' column into datetime.
# - Add 'dy' column to represent day data.
# - Set the index of the dataset in the format like '2012-12-31 20:00:00'.  Hour is added given it is realistic to assume bike sharing demand fluctuate a lot depending on the hours.
# - Drop 'instant' and 'dteday' column at the end given they no longer any values in data analysis nor in bulding the predictive model.

# %%
bike = pd.read_csv('bike.csv')

# %%
# Convert 'dteday' column to datetime
bike['dteday'] = pd.to_datetime(bike['dteday'])

# Convert 'hour' column to string in the format of '00' instead of 0 for example
bike['hr'] = bike['hr'].astype(str).str.zfill(2)

# Combine 'dteday' and 'hour' columns and assign to a new column, datetime
bike['datetime'] = pd.to_datetime(bike['dteday'].astype(str) + ' ' + bike['hr'] + ':00:00')

# %%
# set datetime as and index
bike.set_index('datetime', inplace = True)

# convert hr column back to int64
bike['hr'] = bike['hr'].astype('int64')

# %%
# Insert 'dy' column between 'mnth' and 'hr' columns
bike.insert(loc = bike.columns.get_loc('hr'), column = 'dy', value = bike['dteday'].dt.day)

# drop instant column as this is an identifier and inappropriate as an input to the model
# drop dteday as this is no longer used
bike.drop('instant', axis=1, inplace=True)
bike.drop('dteday', axis=1, inplace=True)

# %% [markdown]
# Check autocorrelation among independent variables

# %%
feature = bike[['temp','atemp','hum','weathersit','workingday','season','hr','yr','cnt','casual','registered']].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(feature, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Given 'temp' and 'atemp' are highly correlated, I drop 'atemp' from the dataset.

# %%
bike = bike.drop('atemp', axis=1)

# %%
bike.tail(4)
# Out:
#                      season  yr  mnth  dy  hr  holiday  weekday  workingday  \
# datetime
# 2012-12-31 20:00:00       1   1    12  31  20        0        1           1
# 2012-12-31 21:00:00       1   1    12  31  21        0        1           1
# 2012-12-31 22:00:00       1   1    12  31  22        0        1           1
# 2012-12-31 23:00:00       1   1    12  31  23        0        1           1
#
#                      weathersit  temp   hum  windspeed  casual  registered  \
# datetime
# 2012-12-31 20:00:00           2  0.26  0.60     0.1642       8          81
# 2012-12-31 21:00:00           1  0.26  0.60     0.1642       7          83
# 2012-12-31 22:00:00           1  0.26  0.56     0.1343      13          48
# 2012-12-31 23:00:00           1  0.26  0.65     0.1343      12          37
#
#                      cnt
# datetime
# 2012-12-31 20:00:00   89
# 2012-12-31 21:00:00   90
# 2012-12-31 22:00:00   61
# 2012-12-31 23:00:00   49

# %% [markdown]
# ### 1.2.2. Split the dataset

# %% [markdown]
# Check the trend of the dataset

# %%
# Perform seasonal decomposition for monthly seasonality (24 * 30 indicates month.)
decomposition = seasonal_decompose(bike['cnt'], model='additive', period = 24*30)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(40, 20))

# the original
ax1.plot(bike.index, bike['cnt'], label='Original')
ax1.set_ylabel('Dependent Variable')
ax1.set_title('Seasonal Decomposition')

# the trend
ax2.plot(decomposition.trend.index, decomposition.trend, label='Trend')
ax2.set_ylabel('Trend')

# the seasonal
ax3.plot(decomposition.seasonal.index, decomposition.seasonal, label='Seasonality')
ax3.set_ylabel('Seasonality')

# the residual
ax4.plot(decomposition.resid.index, decomposition.resid, label='Residuals')
ax4.set_ylabel('Residuals')
ax4.set_xlabel('Time')


plt.subplots_adjust(hspace=0.5)
handles, labels = ax1.get_legend_handles_labels()
plt.show()

# %% [markdown]
# - Given it is the time series data, data is split based on the specific timing rather than the ramdom sample picks.
# - Given the data seems to have increasing trend from 2011 and 2012, it is essential to feed 2011 data as well as sufficient amount of 2012 data to train set.
# - And thus, data between 2011-01-01 to 2012-06-30 is fed to the train set, and for the rest of 6 months equivalent data, the first 3 months are assigned as valid set and the rest to the test set.

# %%
train_data = bike[(bike['yr'] == 0) | (bike['yr'] == 1) & (bike['mnth'] <= 6)]
valid_data = bike[(bike['yr'] == 1) & (bike['mnth'] > 6) & (bike['mnth'] < 10)]
test_data = bike[(bike['yr'] == 1) & (bike['mnth'] > 9)]

# %%
assert train_data.shape[0] + valid_data.shape[0] + test_data.shape[0] == bike.shape[0]

# %% [markdown]
# Since the 'casual' and 'registered' columns are subsets of the 'cnt' column and I assume that casual and registered users behave differently, <br>
# I will take an approarch where each columns are predicted separately and added together in the end to predic 'cnt' column.
#
# Considering the above, three types of split data are introduced:
# - 1. Casual: Predicting 'casual' and then summing it up with the projected 'registered' to find 'cnt'.
# - 2. Registered: Predicting 'registered' and then summing it up with the projected 'casual' to find 'cnt'.
# - 3. Cnt: for assessing the loss of the prediction model using 1.2.

# %%
# 1. casual
X_train_c = train_data.drop(['cnt','casual','registered'], axis=1)
y_train_c = train_data['casual']

X_valid_c = valid_data.drop(['cnt','casual','registered'], axis=1)
y_valid_c = valid_data['casual']

X_test_c = test_data.drop(['cnt','casual','registered'], axis=1)
y_test_c = test_data['casual']

# %%
# 2. registered
X_train_r = train_data.drop(['cnt','casual','registered'], axis=1)
y_train_r = train_data['registered']

X_valid_r = valid_data.drop(['cnt','casual','registered'], axis=1)
y_valid_r = valid_data['registered']

X_test_r = test_data.drop(['cnt','casual','registered'], axis=1)
y_test_r = test_data['registered']

# %%
# 3. cnt
y_train = train_data['cnt']
y_valid = valid_data['cnt']
y_test = test_data['cnt']

# %% [markdown]
# ### 1.2.3. train LSTM model

# %% [markdown]
# #### 1.2.3.1 casual

# %%
# Define the model architecture
model_LSTM_c = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_c.shape[1],)),
    Dropout(0.2),
    BatchNormalization(),
    Dense(64, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),
    Dense(32, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),
    Dense(1)
])

# Compile the model
optimizer = Adam(learning_rate=0.001)
model_LSTM_c.compile(optimizer = optimizer, 
                   loss='mean_squared_error')

# Create a ModelCheckpoint callback to save the best model weights
checkpoint_c = ModelCheckpoint('model_c_weights.h5', 
                               monitor='val_loss',  
                               save_best_only=True,  
                               mode='min', 
                               verbose=0)

# Fit the model to the training data
model_LSTM_c.fit(X_train_c, y_train_c, 
               epochs=100, 
               batch_size=24*5, 
               validation_data=(X_valid_c, y_valid_c),
               callbacks=[checkpoint_c])
# Out:
# Epoch 1/100
# 109/109 [==============================] - 4s 10ms/step - loss: 3039.7642 - val_loss: 6532.2666
# Epoch 2/100
#  10/109 [=>............................] - ETA: 0s - loss: 2588.4807
# c:\Users\User\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 109/109 [==============================] - 1s 7ms/step - loss: 2557.0903 - val_loss: 5860.7363
# Epoch 3/100
# 109/109 [==============================] - 1s 9ms/step - loss: 2013.5011 - val_loss: 4412.3438
# Epoch 4/100
# 109/109 [==============================] - 1s 9ms/step - loss: 1522.6074 - val_loss: 2845.5491
# Epoch 5/100
# 109/109 [==============================] - 1s 12ms/step - loss: 1139.9675 - val_loss: 1723.8134
# Epoch 6/100
# 109/109 [==============================] - 1s 11ms/step - loss: 872.3956 - val_loss: 1950.3899
# Epoch 7/100
# 109/109 [==============================] - 1s 6ms/step - loss: 701.1835 - val_loss: 1258.1334
# Epoch 8/100
# 109/109 [==============================] - 1s 9ms/step - loss: 632.8424 - val_loss: 1133.5635
# Epoch 9/100
# 109/109 [==============================] - 1s 11ms/step - loss: 606.9797 - val_loss: 1057.7106
# Epoch 10/100
# 109/109 [==============================] - 1s 7ms/step - loss: 566.0703 - val_loss: 1120.8661
# Epoch 11/100
# 109/109 [==============================] - 1s 8ms/step - loss: 526.8673 - val_loss: 1135.0338
# Epoch 12/100
# 109/109 [==============================] - 1s 8ms/step - loss: 537.8345 - val_loss: 1068.5885
# Epoch 13/100
# 109/109 [==============================] - 1s 13ms/step - loss: 519.5665 - val_loss: 1367.0449
# Epoch 14/100
# 109/109 [==============================] - 1s 9ms/step - loss: 487.8152 - val_loss: 1092.0310
# Epoch 15/100
# 109/109 [==============================] - 2s 16ms/step - loss: 475.2150 - val_loss: 1038.7964
# Epoch 16/100
# 109/109 [==============================] - 1s 13ms/step - loss: 479.4865 - val_loss: 1050.7852
# Epoch 17/100
# 109/109 [==============================] - 1s 9ms/step - loss: 473.1042 - val_loss: 1386.4508
# Epoch 18/100
# 109/109 [==============================] - 2s 17ms/step - loss: 478.5422 - val_loss: 1095.0448
# Epoch 19/100
# 109/109 [==============================] - 1s 10ms/step - loss: 474.5017 - val_loss: 1226.4977
# Epoch 20/100
# 109/109 [==============================] - 1s 9ms/step - loss: 453.0916 - val_loss: 1123.4312
# Epoch 21/100
# 109/109 [==============================] - 1s 8ms/step - loss: 464.7011 - val_loss: 1536.1495
# Epoch 22/100
# 109/109 [==============================] - 1s 8ms/step - loss: 449.7538 - val_loss: 1064.6161
# Epoch 23/100
# 109/109 [==============================] - 1s 5ms/step - loss: 467.4910 - val_loss: 1105.3512
# Epoch 24/100
# 109/109 [==============================] - 1s 6ms/step - loss: 452.6497 - val_loss: 1334.4740
# Epoch 25/100
# 109/109 [==============================] - 1s 5ms/step - loss: 420.9879 - val_loss: 1163.0938
# Epoch 26/100
# 109/109 [==============================] - 1s 5ms/step - loss: 429.0118 - val_loss: 1228.8451
# Epoch 27/100
# 109/109 [==============================] - 1s 5ms/step - loss: 442.0423 - val_loss: 1074.9871
# Epoch 28/100
# 109/109 [==============================] - 1s 5ms/step - loss: 436.3667 - val_loss: 1155.7185
# Epoch 29/100
# 109/109 [==============================] - 1s 5ms/step - loss: 435.4503 - val_loss: 1370.9241
# Epoch 30/100
# 109/109 [==============================] - 1s 5ms/step - loss: 422.2852 - val_loss: 1074.8953
# Epoch 31/100
# 109/109 [==============================] - 1s 6ms/step - loss: 448.3604 - val_loss: 1311.1359
# Epoch 32/100
# 109/109 [==============================] - 1s 5ms/step - loss: 417.6696 - val_loss: 1065.5385
# Epoch 33/100
# 109/109 [==============================] - 1s 6ms/step - loss: 408.0511 - val_loss: 1380.1735
# Epoch 34/100
# 109/109 [==============================] - 1s 8ms/step - loss: 447.6483 - val_loss: 1658.4430
# Epoch 35/100
# 109/109 [==============================] - 1s 7ms/step - loss: 408.3045 - val_loss: 1259.0758
# Epoch 36/100
# 109/109 [==============================] - 1s 9ms/step - loss: 441.3235 - val_loss: 1349.9352
# Epoch 37/100
# 109/109 [==============================] - 1s 7ms/step - loss: 397.1624 - val_loss: 1229.8679
# Epoch 38/100
# 109/109 [==============================] - 1s 6ms/step - loss: 410.4821 - val_loss: 1400.5037
# Epoch 39/100
# 109/109 [==============================] - 1s 5ms/step - loss: 411.6689 - val_loss: 1208.1344
# Epoch 40/100
# 109/109 [==============================] - 1s 5ms/step - loss: 412.9290 - val_loss: 1334.9392
# Epoch 41/100
# 109/109 [==============================] - 1s 5ms/step - loss: 409.5011 - val_loss: 1079.7440
# Epoch 42/100
# 109/109 [==============================] - 1s 5ms/step - loss: 395.1122 - val_loss: 1294.6470
# Epoch 43/100
# 109/109 [==============================] - 1s 6ms/step - loss: 394.6813 - val_loss: 1180.2709
# Epoch 44/100
# 109/109 [==============================] - 1s 5ms/step - loss: 410.3236 - val_loss: 1169.6456
# Epoch 45/100
# 109/109 [==============================] - 1s 6ms/step - loss: 406.8327 - val_loss: 1507.3866
# Epoch 46/100
# 109/109 [==============================] - 1s 5ms/step - loss: 392.4777 - val_loss: 1236.9390
# Epoch 47/100
# 109/109 [==============================] - 1s 5ms/step - loss: 390.4612 - val_loss: 1238.7935
# Epoch 48/100
# 109/109 [==============================] - 1s 5ms/step - loss: 407.5038 - val_loss: 1152.2186
# Epoch 49/100
# 109/109 [==============================] - 1s 6ms/step - loss: 385.4644 - val_loss: 1191.6567
# Epoch 50/100
# 109/109 [==============================] - 1s 5ms/step - loss: 402.1613 - val_loss: 1096.3937
# Epoch 51/100
# 109/109 [==============================] - 1s 5ms/step - loss: 377.6350 - val_loss: 1367.3713
# Epoch 52/100
# 109/109 [==============================] - 1s 5ms/step - loss: 382.8274 - val_loss: 1163.8429
# Epoch 53/100
# 109/109 [==============================] - 1s 5ms/step - loss: 377.9261 - val_loss: 1113.9871
# Epoch 54/100
# 109/109 [==============================] - 1s 5ms/step - loss: 389.0338 - val_loss: 1138.3199
# Epoch 55/100
# 109/109 [==============================] - 1s 5ms/step - loss: 387.4618 - val_loss: 1229.2771
# Epoch 56/100
# 109/109 [==============================] - 1s 6ms/step - loss: 374.5264 - val_loss: 1267.7540
# Epoch 57/100
# 109/109 [==============================] - 1s 5ms/step - loss: 397.9372 - val_loss: 1179.4038
# Epoch 58/100
# 109/109 [==============================] - 1s 6ms/step - loss: 381.9987 - val_loss: 1124.1235
# Epoch 59/100
# 109/109 [==============================] - 1s 6ms/step - loss: 389.7091 - val_loss: 1438.6353
# Epoch 60/100
# 109/109 [==============================] - 1s 6ms/step - loss: 382.6544 - val_loss: 1037.8398
# Epoch 61/100
# 109/109 [==============================] - 1s 5ms/step - loss: 372.1844 - val_loss: 1254.7592
# Epoch 62/100
# 109/109 [==============================] - 1s 9ms/step - loss: 361.4073 - val_loss: 1453.9279
# Epoch 63/100
# 109/109 [==============================] - 1s 6ms/step - loss: 370.4532 - val_loss: 1223.8607
# Epoch 64/100
# 109/109 [==============================] - 1s 5ms/step - loss: 381.5360 - val_loss: 1213.9926
# Epoch 65/100
# 109/109 [==============================] - 1s 11ms/step - loss: 384.3908 - val_loss: 1147.4575
# Epoch 66/100
# 109/109 [==============================] - 1s 9ms/step - loss: 401.7474 - val_loss: 1134.8488
# Epoch 67/100
# 109/109 [==============================] - 1s 7ms/step - loss: 377.9207 - val_loss: 1221.3202
# Epoch 68/100
# 109/109 [==============================] - 1s 7ms/step - loss: 369.7935 - val_loss: 1250.3370
# Epoch 69/100
# 109/109 [==============================] - 1s 7ms/step - loss: 381.9072 - val_loss: 1308.7178
# Epoch 70/100
# 109/109 [==============================] - 1s 5ms/step - loss: 380.4473 - val_loss: 981.9299
# Epoch 71/100
# 109/109 [==============================] - 1s 5ms/step - loss: 364.2714 - val_loss: 1414.1934
# Epoch 72/100
# 109/109 [==============================] - 1s 6ms/step - loss: 364.0522 - val_loss: 1209.0605
# Epoch 73/100
# 109/109 [==============================] - 1s 5ms/step - loss: 360.2039 - val_loss: 1287.4789
# Epoch 74/100
# 109/109 [==============================] - 1s 8ms/step - loss: 399.9316 - val_loss: 1319.1415
# Epoch 75/100
# 109/109 [==============================] - 1s 10ms/step - loss: 380.4252 - val_loss: 1313.3876
# Epoch 76/100
# 109/109 [==============================] - 1s 7ms/step - loss: 369.8777 - val_loss: 1128.2029
# Epoch 77/100
# 109/109 [==============================] - 1s 8ms/step - loss: 375.7898 - val_loss: 1115.7942
# Epoch 78/100
# 109/109 [==============================] - 1s 5ms/step - loss: 378.4209 - val_loss: 1184.0760
# Epoch 79/100
# 109/109 [==============================] - 1s 5ms/step - loss: 380.9586 - val_loss: 1293.6265
# Epoch 80/100
# 109/109 [==============================] - 1s 5ms/step - loss: 375.4641 - val_loss: 1463.7671
# Epoch 81/100
# 109/109 [==============================] - 1s 5ms/step - loss: 355.3372 - val_loss: 1313.4495
# Epoch 82/100
# 109/109 [==============================] - 1s 5ms/step - loss: 375.0923 - val_loss: 1078.7889
# Epoch 83/100
# 109/109 [==============================] - 1s 6ms/step - loss: 356.4456 - val_loss: 988.1745
# Epoch 84/100
# 109/109 [==============================] - 1s 6ms/step - loss: 374.4746 - val_loss: 1106.4321
# Epoch 85/100
# 109/109 [==============================] - 1s 6ms/step - loss: 373.7520 - val_loss: 1337.9175
# Epoch 86/100
# 109/109 [==============================] - 1s 6ms/step - loss: 354.1019 - val_loss: 1110.0260
# Epoch 87/100
# 109/109 [==============================] - 1s 5ms/step - loss: 356.8565 - val_loss: 1146.9443
# Epoch 88/100
# 109/109 [==============================] - 1s 7ms/step - loss: 365.5847 - val_loss: 1480.3337
# Epoch 89/100
# 109/109 [==============================] - 1s 5ms/step - loss: 372.7111 - val_loss: 1228.6534
# Epoch 90/100
# 109/109 [==============================] - 1s 5ms/step - loss: 349.1086 - val_loss: 1270.0491
# Epoch 91/100
# 109/109 [==============================] - 1s 5ms/step - loss: 353.7603 - val_loss: 1044.0709
# Epoch 92/100
# 109/109 [==============================] - 1s 6ms/step - loss: 360.3877 - val_loss: 1101.8199
# Epoch 93/100
# 109/109 [==============================] - 1s 6ms/step - loss: 367.5710 - val_loss: 992.3922
# Epoch 94/100
# 109/109 [==============================] - 1s 8ms/step - loss: 372.4601 - val_loss: 1043.5685
# Epoch 95/100
# 109/109 [==============================] - 1s 7ms/step - loss: 369.0117 - val_loss: 1210.6008
# Epoch 96/100
# 109/109 [==============================] - 1s 7ms/step - loss: 371.5356 - val_loss: 1040.7639
# Epoch 97/100
# 109/109 [==============================] - 1s 5ms/step - loss: 360.9117 - val_loss: 1180.8702
# Epoch 98/100
# 109/109 [==============================] - 1s 5ms/step - loss: 366.8329 - val_loss: 1106.2897
# Epoch 99/100
# 109/109 [==============================] - 1s 6ms/step - loss: 341.9207 - val_loss: 1196.2739
# Epoch 100/100
# 109/109 [==============================] - 1s 5ms/step - loss: 358.0726 - val_loss: 1034.7529

# %%
# prediction
train_c_pred = model_LSTM_c.predict(X_train_c.values)
valid_c_pred = model_LSTM_c.predict(X_valid_c.values)
test_c_pred = model_LSTM_c.predict(X_test_c.values)

# predicted result
train_c_MAPE_lstm = mean_absolute_percentage_error(y_train_c, train_c_pred)
valid_c_MAPE_lstm = mean_absolute_percentage_error(y_valid_c, valid_c_pred)
test_c_MAPE_lstm = mean_absolute_percentage_error(y_test_c, test_c_pred)

print('train(casual) MAPE: ', train_c_MAPE_lstm)
print('valid(casual) MAPE: ', valid_c_MAPE_lstm)
print('test(casual) MAPE: ', test_c_MAPE_lstm)
# Out:
# 407/407 [==============================] - 1s 2ms/step
# 69/69 [==============================] - 0s 2ms/step
# 68/68 [==============================] - 0s 2ms/step
# train(casual) MAPE:  1614839119636911.8
# valid(casual) MAPE:  918498130286859.6
# test(casual) MAPE:  1691736906251744.2

# %% [markdown]
# #### 1.2.3.2. Registered

# %%
# Define the model architecture
model_LSTM_r = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_r.shape[1],)),
    Dropout(0.2),
    BatchNormalization(),
    Dense(64, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),
    Dense(32, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),
    Dense(1)
])

# Compile the model
optimizer = Adam(learning_rate=0.001)
model_LSTM_r.compile(optimizer = optimizer, 
                   loss='mean_squared_error')

# Create a ModelCheckpoint callback to save the best model weights
checkpoint_r = ModelCheckpoint('model_r_weights.h5', 
                               monitor='val_loss',  
                               save_best_only=True,  
                               mode='min', 
                               verbose=0)

# Fit the model to the training data
model_LSTM_r.fit(X_train_r, y_train_r, 
               epochs=100, 
               batch_size=24*5, 
               validation_data=(X_valid_r, y_valid_r),
               callbacks=[checkpoint_r])
# Out:
# Epoch 1/100
# 109/109 [==============================] - 5s 8ms/step - loss: 35063.8477 - val_loss: 88659.0625
# Epoch 2/100
#  23/109 [=====>........................] - ETA: 0s - loss: 33797.1719
# c:\Users\User\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 109/109 [==============================] - 1s 7ms/step - loss: 33490.7461 - val_loss: 84392.9531
# Epoch 3/100
# 109/109 [==============================] - 1s 11ms/step - loss: 31433.8633 - val_loss: 75688.5547
# Epoch 4/100
# 109/109 [==============================] - 1s 6ms/step - loss: 28974.0293 - val_loss: 69065.9375
# Epoch 5/100
# 109/109 [==============================] - 2s 16ms/step - loss: 26237.7090 - val_loss: 68695.0312
# Epoch 6/100
# 109/109 [==============================] - 1s 10ms/step - loss: 23328.2617 - val_loss: 57276.2461
# Epoch 7/100
# 109/109 [==============================] - 1s 10ms/step - loss: 20481.8340 - val_loss: 56013.5508
# Epoch 8/100
# 109/109 [==============================] - 1s 6ms/step - loss: 17543.5508 - val_loss: 46219.7617
# Epoch 9/100
# 109/109 [==============================] - 2s 15ms/step - loss: 14894.7080 - val_loss: 45602.8555
# Epoch 10/100
# 109/109 [==============================] - 1s 7ms/step - loss: 12463.5684 - val_loss: 35569.3984
# Epoch 11/100
# 109/109 [==============================] - 1s 9ms/step - loss: 10465.6357 - val_loss: 33592.8828
# Epoch 12/100
# 109/109 [==============================] - 2s 18ms/step - loss: 8798.8984 - val_loss: 21751.7227
# Epoch 13/100
# 109/109 [==============================] - 1s 9ms/step - loss: 7700.5283 - val_loss: 21134.4473
# Epoch 14/100
# 109/109 [==============================] - 1s 12ms/step - loss: 6796.7324 - val_loss: 17064.3867
# Epoch 15/100
# 109/109 [==============================] - 2s 16ms/step - loss: 6113.3306 - val_loss: 12257.9189
# Epoch 16/100
# 109/109 [==============================] - 1s 9ms/step - loss: 5703.2402 - val_loss: 12480.0938
# Epoch 17/100
# 109/109 [==============================] - 1s 6ms/step - loss: 5318.9961 - val_loss: 16263.0107
# Epoch 18/100
# 109/109 [==============================] - 1s 13ms/step - loss: 5136.0142 - val_loss: 12466.2998
# Epoch 19/100
# 109/109 [==============================] - 1s 7ms/step - loss: 4709.9541 - val_loss: 13098.8057
# Epoch 20/100
# 109/109 [==============================] - 1s 13ms/step - loss: 4489.1826 - val_loss: 13099.9170
# Epoch 21/100
# 109/109 [==============================] - 1s 8ms/step - loss: 4648.8442 - val_loss: 9118.9062
# Epoch 22/100
# 109/109 [==============================] - 1s 5ms/step - loss: 4617.4604 - val_loss: 10163.3076
# Epoch 23/100
# 109/109 [==============================] - 1s 5ms/step - loss: 4531.5298 - val_loss: 9661.9131
# Epoch 24/100
# 109/109 [==============================] - 1s 8ms/step - loss: 4402.7891 - val_loss: 7038.8081
# Epoch 25/100
# 109/109 [==============================] - 1s 5ms/step - loss: 4293.4204 - val_loss: 9298.4873
# Epoch 26/100
# 109/109 [==============================] - 1s 12ms/step - loss: 4117.2007 - val_loss: 8125.5054
# Epoch 27/100
# 109/109 [==============================] - 1s 13ms/step - loss: 4159.4893 - val_loss: 7457.3687
# Epoch 28/100
# 109/109 [==============================] - 1s 13ms/step - loss: 4086.7271 - val_loss: 8564.1338
# Epoch 29/100
# 109/109 [==============================] - 2s 14ms/step - loss: 4104.7568 - val_loss: 10287.0049
# Epoch 30/100
# 109/109 [==============================] - 1s 11ms/step - loss: 4092.8628 - val_loss: 6888.4424
# Epoch 31/100
# 109/109 [==============================] - 1s 9ms/step - loss: 3927.6414 - val_loss: 8485.9688
# Epoch 32/100
# 109/109 [==============================] - 1s 12ms/step - loss: 4060.7512 - val_loss: 10038.8994
# Epoch 33/100
# 109/109 [==============================] - 1s 13ms/step - loss: 3958.1511 - val_loss: 11973.7422
# Epoch 34/100
# 109/109 [==============================] - 1s 11ms/step - loss: 4021.3928 - val_loss: 6815.1099
# Epoch 35/100
# 109/109 [==============================] - 1s 10ms/step - loss: 3978.4333 - val_loss: 11145.9131
# Epoch 36/100
# 109/109 [==============================] - 1s 9ms/step - loss: 3854.1099 - val_loss: 7098.9707
# Epoch 37/100
# 109/109 [==============================] - 1s 8ms/step - loss: 3857.8003 - val_loss: 6800.5249
# Epoch 38/100
# 109/109 [==============================] - 2s 21ms/step - loss: 3743.6687 - val_loss: 7126.3477
# Epoch 39/100
# 109/109 [==============================] - 1s 9ms/step - loss: 3810.7957 - val_loss: 6730.4590
# Epoch 40/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3838.9243 - val_loss: 6812.4287
# Epoch 41/100
# 109/109 [==============================] - 2s 18ms/step - loss: 3742.5281 - val_loss: 6699.2588
# Epoch 42/100
# 109/109 [==============================] - 1s 13ms/step - loss: 3630.6777 - val_loss: 6030.0283
# Epoch 43/100
# 109/109 [==============================] - 1s 11ms/step - loss: 3792.1606 - val_loss: 7351.0068
# Epoch 44/100
# 109/109 [==============================] - 2s 16ms/step - loss: 3547.1223 - val_loss: 6727.4541
# Epoch 45/100
# 109/109 [==============================] - 1s 9ms/step - loss: 3585.0427 - val_loss: 5959.4814
# Epoch 46/100
# 109/109 [==============================] - 2s 18ms/step - loss: 3545.8301 - val_loss: 8021.7788
# Epoch 47/100
# 109/109 [==============================] - 1s 11ms/step - loss: 3596.2532 - val_loss: 6807.9116
# Epoch 48/100
# 109/109 [==============================] - 1s 10ms/step - loss: 3499.0579 - val_loss: 5500.0542
# Epoch 49/100
# 109/109 [==============================] - 2s 23ms/step - loss: 3659.9839 - val_loss: 6131.7920
# Epoch 50/100
# 109/109 [==============================] - 1s 12ms/step - loss: 3607.3105 - val_loss: 8163.8442
# Epoch 51/100
# 109/109 [==============================] - 2s 15ms/step - loss: 3497.0669 - val_loss: 7270.3442
# Epoch 52/100
# 109/109 [==============================] - 2s 15ms/step - loss: 3373.0107 - val_loss: 5329.0933
# Epoch 53/100
# 109/109 [==============================] - 1s 10ms/step - loss: 3564.3857 - val_loss: 6351.8022
# Epoch 54/100
# 109/109 [==============================] - 1s 10ms/step - loss: 3496.9792 - val_loss: 5860.1362
# Epoch 55/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3464.7617 - val_loss: 8176.0635
# Epoch 56/100
# 109/109 [==============================] - 1s 11ms/step - loss: 3502.2043 - val_loss: 6696.9360
# Epoch 57/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3396.7253 - val_loss: 6433.8779
# Epoch 58/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3341.8291 - val_loss: 8618.5635
# Epoch 59/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3528.0068 - val_loss: 5709.6445
# Epoch 60/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3380.2920 - val_loss: 6667.0298
# Epoch 61/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3249.0491 - val_loss: 7815.6577
# Epoch 62/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3329.2043 - val_loss: 7766.8271
# Epoch 63/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3293.9104 - val_loss: 5709.4453
# Epoch 64/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3258.7056 - val_loss: 5105.3916
# Epoch 65/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3282.0422 - val_loss: 4578.3447
# Epoch 66/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3337.9573 - val_loss: 5230.8110
# Epoch 67/100
# 109/109 [==============================] - 1s 8ms/step - loss: 3357.4846 - val_loss: 8260.2900
# Epoch 68/100
# 109/109 [==============================] - 1s 8ms/step - loss: 3312.9041 - val_loss: 5305.9502
# Epoch 69/100
# 109/109 [==============================] - 1s 11ms/step - loss: 3247.2903 - val_loss: 6493.7744
# Epoch 70/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3337.4194 - val_loss: 8651.4385
# Epoch 71/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3249.0376 - val_loss: 6466.8037
# Epoch 72/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3322.1199 - val_loss: 5696.8506
# Epoch 73/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3276.6697 - val_loss: 5997.3403
# Epoch 74/100
# 109/109 [==============================] - 1s 9ms/step - loss: 3276.7891 - val_loss: 7299.7534
# Epoch 75/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3309.4343 - val_loss: 6379.4634
# Epoch 76/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3049.6401 - val_loss: 4981.8784
# Epoch 77/100
# 109/109 [==============================] - 1s 8ms/step - loss: 3191.1672 - val_loss: 5518.5459
# Epoch 78/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3221.3772 - val_loss: 6736.0737
# Epoch 79/100
# 109/109 [==============================] - 1s 9ms/step - loss: 3405.0222 - val_loss: 10802.9697
# Epoch 80/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3280.1907 - val_loss: 5972.1875
# Epoch 81/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3292.3977 - val_loss: 7516.5718
# Epoch 82/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3245.6838 - val_loss: 7506.9087
# Epoch 83/100
# 109/109 [==============================] - 1s 9ms/step - loss: 3290.6599 - val_loss: 8563.8525
# Epoch 84/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3122.1675 - val_loss: 5610.6694
# Epoch 85/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3202.9734 - val_loss: 8567.1895
# Epoch 86/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3284.8208 - val_loss: 6149.5112
# Epoch 87/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3201.2107 - val_loss: 8077.7627
# Epoch 88/100
# 109/109 [==============================] - 1s 5ms/step - loss: 2969.6030 - val_loss: 5687.1743
# Epoch 89/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3066.8972 - val_loss: 6030.5220
# Epoch 90/100
# 109/109 [==============================] - 1s 6ms/step - loss: 3106.8760 - val_loss: 7024.4043
# Epoch 91/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3077.5168 - val_loss: 7222.7568
# Epoch 92/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3036.0718 - val_loss: 4638.9336
# Epoch 93/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3091.6548 - val_loss: 9378.6543
# Epoch 94/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3156.5500 - val_loss: 6347.8950
# Epoch 95/100
# 109/109 [==============================] - 1s 5ms/step - loss: 3215.1519 - val_loss: 6259.3384
# Epoch 96/100
# 109/109 [==============================] - 1s 8ms/step - loss: 3001.0491 - val_loss: 5571.2456
# Epoch 97/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3162.5349 - val_loss: 7116.5459
# Epoch 98/100
# 109/109 [==============================] - 1s 8ms/step - loss: 3069.3772 - val_loss: 4661.6309
# Epoch 99/100
# 109/109 [==============================] - 1s 7ms/step - loss: 3064.6621 - val_loss: 4745.4434
# Epoch 100/100
# 109/109 [==============================] - 1s 8ms/step - loss: 2984.4854 - val_loss: 7371.5454

# %%
# prediction
train_r_pred = model_LSTM_r.predict(X_train_r.values)
valid_r_pred = model_LSTM_r.predict(X_valid_r.values)
test_r_pred = model_LSTM_r.predict(X_test_r.values)

# predicted result
train_r_MAPE_lstm = mean_absolute_percentage_error(y_train_r, train_r_pred)
valid_r_MAPE_lstm = mean_absolute_percentage_error(y_valid_r, valid_r_pred)
test_r_MAPE_lstm = mean_absolute_percentage_error(y_test_r, test_r_pred)

print('train(registered) MAPE: ', train_r_MAPE_lstm)
print('valid(registered) MAPE: ', valid_r_MAPE_lstm)
print('test(registered) MAPE: ', test_r_MAPE_lstm)
# Out:
# 407/407 [==============================] - 1s 2ms/step
# 69/69 [==============================] - 0s 2ms/step
# 68/68 [==============================] - 0s 2ms/step
# train(registered) MAPE:  65615025745169.336
# valid(registered) MAPE:  0.43841742496817065
# test(registered) MAPE:  23121068917099.496

# %% [markdown]
# #### 1.2.3.3. Combined result

# %% [markdown]
# train ( y vs yhat(casual_pred + register_pred) )

# %%
combined_result_train = y_train.copy()

combined_result_train = pd.DataFrame(combined_result_train).join(pd.DataFrame(train_c_pred, index = y_train.index))
combined_result_train = combined_result_train.rename(columns={'cnt': 'cnt', 0: 'casual_pred'})

combined_result_train = combined_result_train.join(pd.DataFrame(train_r_pred, index = y_train.index))
combined_result_train = combined_result_train.rename(columns={'cnt': 'cnt', 'casual_pred': 'casual_pred', 0: 'registered_pred'})

combined_result_train['cnt_pred'] = round(combined_result_train['casual_pred'] + combined_result_train['registered_pred'],0)
combined_result_train
# Out:
#                      cnt  casual_pred  registered_pred  cnt_pred
# datetime
# 2011-01-01 00:00:00   16     7.706887        41.051491      49.0
# 2011-01-01 01:00:00   40     2.833287        27.691196      31.0
# 2011-01-01 02:00:00   32     0.015468         9.970799      10.0
# 2011-01-01 03:00:00   13     0.175824         4.272127       4.0
# 2011-01-01 04:00:00    1     0.457782         5.018802       5.0
# ...                  ...          ...              ...       ...
# 2012-06-30 19:00:00  374   175.626282       242.701370     418.0
# 2012-06-30 20:00:00  292   151.922913       208.544083     360.0
# 2012-06-30 21:00:00  213   113.604256       180.142166     294.0
# 2012-06-30 22:00:00  172    87.808319       162.672440     250.0
# 2012-06-30 23:00:00  152    68.545303       152.224991     221.0
#
# [13003 rows x 4 columns]

# %% [markdown]
# valid ( y vs yhat(casual_pred + register_pred) )

# %%
combined_result_valid = y_valid.copy()

combined_result_valid = pd.DataFrame(combined_result_valid).join(pd.DataFrame(valid_c_pred, index = y_valid.index))
combined_result_valid = combined_result_valid.rename(columns={'cnt': 'cnt', 0: 'casual_pred'})

combined_result_valid = combined_result_valid.join(pd.DataFrame(valid_r_pred, index = y_valid.index))
combined_result_valid = combined_result_valid.rename(columns={'cnt': 'cnt', 'casual_pred': 'casual_pred', 0: 'registered_pred'})

combined_result_valid['cnt_pred'] = round(combined_result_valid['casual_pred'] + combined_result_valid['registered_pred'],0)
combined_result_valid
# Out:
#                      cnt  casual_pred  registered_pred  cnt_pred
# datetime
# 2012-07-01 00:00:00  149    35.132641        83.537552     119.0
# 2012-07-01 01:00:00   93    32.909103        84.953308     118.0
# 2012-07-01 02:00:00   90    20.857018        75.449265      96.0
# 2012-07-01 03:00:00   33    15.891969        55.981541      72.0
# 2012-07-01 04:00:00    4     6.988966        36.922546      44.0
# ...                  ...          ...              ...       ...
# 2012-09-30 19:00:00  257    46.727119       122.392525     169.0
# 2012-09-30 20:00:00  194    35.489861       104.407112     140.0
# 2012-09-30 21:00:00  123    46.293800       141.535309     188.0
# 2012-09-30 22:00:00   91    34.740860       123.293922     158.0
# 2012-09-30 23:00:00   57    24.903549       104.039337     129.0
#
# [2208 rows x 4 columns]

# %% [markdown]
# test ( y vs yhat(casual_pred + register_pred) )

# %%
combined_result_test = y_test.copy()

combined_result_test = pd.DataFrame(combined_result_test).join(pd.DataFrame(test_c_pred, index = y_test.index))
combined_result_test = combined_result_test.rename(columns={'cnt': 'cnt', 0: 'casual_pred'})

combined_result_test = combined_result_test.join(pd.DataFrame(test_r_pred, index = y_test.index))
combined_result_test = combined_result_test.rename(columns={'cnt': 'cnt', 'casual_pred': 'casual_pred', 0: 'registered_pred'})

combined_result_test['cnt_pred'] = round(combined_result_test['casual_pred'] + combined_result_test['registered_pred'],0)
combined_result_test
# Out:
#                      cnt  casual_pred  registered_pred  cnt_pred
# datetime
# 2012-10-01 00:00:00   45     9.861841        57.593250      67.0
# 2012-10-01 01:00:00   18     7.916420        28.569817      36.0
# 2012-10-01 02:00:00   12     7.462339         5.588157      13.0
# 2012-10-01 03:00:00    7     4.247800         5.525346      10.0
# 2012-10-01 04:00:00   10     4.657768        15.561538      20.0
# ...                  ...          ...              ...       ...
# 2012-12-31 19:00:00  119    10.140220       120.680840     131.0
# 2012-12-31 20:00:00   89     9.318337        86.785507      96.0
# 2012-12-31 21:00:00   90     8.459480        93.082611     102.0
# 2012-12-31 22:00:00   61     7.398156        79.848335      87.0
# 2012-12-31 23:00:00   49     6.049394        66.765999      73.0
#
# [2168 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(y_train.index, y_train.values, label="actual(train dataset)", alpha = 0.5)
ax.plot(y_valid.index, y_valid.values, label="actual(test dataset)", alpha = 0.5)
ax.plot(y_test.index, y_test.values, label="actual(test dataset)", alpha = 0.5)

ax.plot(y_train.index, combined_result_train['cnt_pred'], linestyle="dotted", lw=2,color="m", alpha = 0.5)
ax.plot(y_valid.index, combined_result_valid['cnt_pred'], label="LSTM_valid", linestyle="dotted", lw=2, color="m", alpha = 0.5)
ax.plot(y_test.index, combined_result_test['cnt_pred'], label="LSTM_test", linestyle="dotted", lw=2, color="m", alpha = 0.5) 
plt.legend()

# %%
# predicted result
train_MAPE_lstm = mean_absolute_percentage_error(combined_result_train['cnt'], combined_result_train['cnt_pred'])
valid_MAPE_lstm = mean_absolute_percentage_error(combined_result_valid['cnt'], combined_result_valid['cnt_pred'])
test_MAPE_lstm = mean_absolute_percentage_error(combined_result_test['cnt'], combined_result_test['cnt_pred'])

print('train MAPE is {}'.format(train_MAPE_lstm))
print('valid MAPE is {}'.format(valid_MAPE_lstm))
print('test MAPE is {}'.format(test_MAPE_lstm))
# Out:
# train MAPE is 0.6592009095403286
# valid MAPE is 0.4554081452279803
# test MAPE is 0.7501862376025298

# %% [markdown]
# ### 1.2.4. Performance Evaluation
# - By looking at the visualization, the model captures the high-level time-series trend of the data.
# - For the test set, the loss is more than 0.75 which suggests the model is not accurate enough.
# - Another unique characteristic is the relationship between valid loss and train loss.  In this model, valid loss < train loss which may come from various possible causes such as not enough generalization to unseen data (the valid set was coincidently better fit to the trained model) or too high learning rate.

# %% [markdown]
# ## 1.3.	HYPERPARAMETER TUNING PLAYS A CRUCIAL ROLE IN OPTIMIZING NEURAL NETWORKS. ATTEMPT TO TUNE THE HYPERPARAMETERS OF YOUR MODEL AND ANALYZE THE IMPACT ON ITS PERFORMANCE. (5 POINTS)

# %% [markdown]
# ### 1.3.1. Tune hyperparameters

# %% [markdown]
# The Bayesian Optimization is being applied to tune the following hyperparameters
# - number of neurons per layer
# - dropout rate
# - learning rate
# - batch size

# %% [markdown]
# #### 1.3.1.1. Casual

# %%
def create_model(trial):
    model = Sequential()
    model.add(Dense(trial.suggest_int('units_1', 128, 512), activation='relu', input_shape=(X_train_c.shape[1],)))
    model.add(Dropout(trial.suggest_float('dropout_1', 0.0, 0.5)))
    model.add(BatchNormalization())
    model.add(Dense(trial.suggest_int('units_2', 64, 256), activation='relu'))
    model.add(Dropout(trial.suggest_float('dropout_2', 0.0, 0.5)))
    model.add(BatchNormalization())
    model.add(Dense(trial.suggest_int('units_3', 32, 128), activation='relu'))
    model.add(Dropout(trial.suggest_float('dropout_3', 0.0, 0.5)))
    model.add(BatchNormalization())
    model.add(Dense(1))

    optimizer = Adam(learning_rate=trial.suggest_float('learning_rate', 1e-6, 1e-1, log=True))
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

def objective(trial):
    batch_size = trial.suggest_categorical('batch_size', [64, 128, 256, 512])
    model = create_model(trial)
    history = model.fit(X_train_c, y_train_c, 
                        epochs = 50, 
                        batch_size = batch_size, 
                        validation_data=(X_valid_c, y_valid_c),
                        verbose=0)
    return np.min(history.history['val_loss'])

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10) 
print(f"The best parameters are : \n {study.best_params}")
# Out:
# [I 2023-08-21 23:55:15,692] A new study created in memory with name: no-name-8ed03b66-1804-4b30-90d9-baaf430cffd8
# [I 2023-08-21 23:55:59,863] Trial 0 finished with value: 732.3892211914062 and parameters: {'batch_size': 256, 'units_1': 442, 'dropout_1': 0.002595804557800896, 'units_2': 227, 'dropout_2': 0.08144365465161074, 'units_3': 53, 'dropout_3': 0.4993799244741601, 'learning_rate': 0.0006246220474456041}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-21 23:57:25,988] Trial 1 finished with value: 1589.8236083984375 and parameters: {'batch_size': 64, 'units_1': 507, 'dropout_1': 0.38613535822262857, 'units_2': 185, 'dropout_2': 0.37709097494199256, 'units_3': 121, 'dropout_3': 0.38874885799035797, 'learning_rate': 3.104509070284468e-05}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-21 23:58:04,352] Trial 2 finished with value: 941.446044921875 and parameters: {'batch_size': 256, 'units_1': 333, 'dropout_1': 0.09074809270403345, 'units_2': 148, 'dropout_2': 0.44472165027186694, 'units_3': 77, 'dropout_3': 0.3428056457476723, 'learning_rate': 0.00027069811539665717}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-21 23:58:47,200] Trial 3 finished with value: 4006.22509765625 and parameters: {'batch_size': 256, 'units_1': 464, 'dropout_1': 0.3144987673889843, 'units_2': 173, 'dropout_2': 0.4400854450252008, 'units_3': 92, 'dropout_3': 0.4241415880283627, 'learning_rate': 4.475774961732919e-05}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-21 23:59:13,019] Trial 4 finished with value: 6619.11328125 and parameters: {'batch_size': 512, 'units_1': 158, 'dropout_1': 0.20342183546533377, 'units_2': 193, 'dropout_2': 0.033421417531613484, 'units_3': 39, 'dropout_3': 0.36778150599245285, 'learning_rate': 6.098296785873682e-06}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-22 00:00:03,951] Trial 5 finished with value: 955.4503173828125 and parameters: {'batch_size': 128, 'units_1': 331, 'dropout_1': 0.35588755683298745, 'units_2': 200, 'dropout_2': 0.21828656753551734, 'units_3': 39, 'dropout_3': 0.3805961101473009, 'learning_rate': 0.0009471759556140564}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-22 00:01:12,453] Trial 6 finished with value: 5376.7431640625 and parameters: {'batch_size': 64, 'units_1': 445, 'dropout_1': 0.48400492012807617, 'units_2': 136, 'dropout_2': 0.28072528055104484, 'units_3': 90, 'dropout_3': 0.3392165361366578, 'learning_rate': 8.525251295322161e-06}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-22 00:02:05,727] Trial 7 finished with value: 1621.5185546875 and parameters: {'batch_size': 64, 'units_1': 353, 'dropout_1': 0.3826055253890999, 'units_2': 96, 'dropout_2': 0.32789987126276765, 'units_3': 119, 'dropout_3': 0.2091782051476887, 'learning_rate': 3.1647927518718186e-05}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-22 00:03:15,229] Trial 8 finished with value: 962.5222778320312 and parameters: {'batch_size': 64, 'units_1': 303, 'dropout_1': 0.40948037387657715, 'units_2': 224, 'dropout_2': 0.3780043112006757, 'units_3': 67, 'dropout_3': 0.3251113023809413, 'learning_rate': 0.009056653989939266}. Best is trial 0 with value: 732.3892211914062.
# [I 2023-08-22 00:03:40,521] Trial 9 finished with value: 766.3805541992188 and parameters: {'batch_size': 256, 'units_1': 147, 'dropout_1': 0.287474247177789, 'units_2': 85, 'dropout_2': 0.17222709962692623, 'units_3': 75, 'dropout_3': 0.11087897223783638, 'learning_rate': 0.013113410886204876}. Best is trial 0 with value: 732.3892211914062.
# The best parameters are :
#  {'batch_size': 256, 'units_1': 442, 'dropout_1': 0.002595804557800896, 'units_2': 227, 'dropout_2': 0.08144365465161074, 'units_3': 53, 'dropout_3': 0.4993799244741601, 'learning_rate': 0.0006246220474456041}

# %% [markdown]
# ### 1.3.1.2. Registered

# %%
def create_model(trial):
    model = Sequential()
    model.add(Dense(trial.suggest_int('units_1', 128, 512), activation='relu', input_shape=(X_train_r.shape[1],)))
    model.add(Dropout(trial.suggest_float('dropout_1', 0.0, 0.5)))
    model.add(BatchNormalization())
    model.add(Dense(trial.suggest_int('units_2', 64, 256), activation='relu'))
    model.add(Dropout(trial.suggest_float('dropout_2', 0.0, 0.5)))
    model.add(BatchNormalization())
    model.add(Dense(trial.suggest_int('units_3', 32, 128), activation='relu'))
    model.add(Dropout(trial.suggest_float('dropout_3', 0.0, 0.5)))
    model.add(BatchNormalization())
    model.add(Dense(1))

    optimizer = Adam(learning_rate=trial.suggest_float('learning_rate', 1e-6, 1e-1, log=True))
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

def objective(trial):
    batch_size = trial.suggest_categorical('batch_size', [64, 128, 256, 512])
    model = create_model(trial)
    history = model.fit(X_train_r, y_train_r, 
                        epochs=50, 
                        batch_size = batch_size, 
                        validation_data=(X_valid_r, y_valid_r),
                        verbose=0)
    return np.min(history.history['val_loss'])

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=15) 
print(f"The best parameters are : \n {study.best_params}")
# Out:
# [I 2023-08-22 00:05:11,202] A new study created in memory with name: no-name-87a30baf-e442-471e-86f8-10c48cd2f8a5
# [I 2023-08-22 00:06:22,761] Trial 0 finished with value: 14227.5537109375 and parameters: {'batch_size': 64, 'units_1': 209, 'dropout_1': 0.2405337664304661, 'units_2': 181, 'dropout_2': 0.4540020017781669, 'units_3': 107, 'dropout_3': 0.10400742611293823, 'learning_rate': 0.023533125609025377}. Best is trial 0 with value: 14227.5537109375.
# [I 2023-08-22 00:07:41,431] Trial 1 finished with value: 15336.556640625 and parameters: {'batch_size': 64, 'units_1': 491, 'dropout_1': 0.47614290670453807, 'units_2': 115, 'dropout_2': 0.24900027269238334, 'units_3': 34, 'dropout_3': 0.21865006660859282, 'learning_rate': 0.0001676657337733469}. Best is trial 0 with value: 14227.5537109375.
# [I 2023-08-22 00:08:36,648] Trial 2 finished with value: 90311.671875 and parameters: {'batch_size': 128, 'units_1': 502, 'dropout_1': 0.13524035630009795, 'units_2': 159, 'dropout_2': 0.2163376493636167, 'units_3': 87, 'dropout_3': 0.2831690630062292, 'learning_rate': 1.3128343635522504e-06}. Best is trial 0 with value: 14227.5537109375.
# [I 2023-08-22 00:09:37,778] Trial 3 finished with value: 90957.28125 and parameters: {'batch_size': 128, 'units_1': 318, 'dropout_1': 0.30535183467152965, 'units_2': 133, 'dropout_2': 0.25566301923696927, 'units_3': 120, 'dropout_3': 0.4440869028313658, 'learning_rate': 1.773752561702815e-06}. Best is trial 0 with value: 14227.5537109375.
# [I 2023-08-22 00:10:50,030] Trial 4 finished with value: 7630.140625 and parameters: {'batch_size': 64, 'units_1': 244, 'dropout_1': 0.43676510109674704, 'units_2': 108, 'dropout_2': 0.05730534833502837, 'units_3': 92, 'dropout_3': 0.0807740735540981, 'learning_rate': 0.0002226329978062454}. Best is trial 4 with value: 7630.140625.
# [I 2023-08-22 00:11:24,818] Trial 5 finished with value: 10445.48046875 and parameters: {'batch_size': 128, 'units_1': 151, 'dropout_1': 0.4837603823575341, 'units_2': 96, 'dropout_2': 0.44260315025560476, 'units_3': 69, 'dropout_3': 0.04060901925017513, 'learning_rate': 0.002002646966762662}. Best is trial 4 with value: 7630.140625.
# [I 2023-08-22 00:12:44,814] Trial 6 finished with value: 6142.8759765625 and parameters: {'batch_size': 64, 'units_1': 327, 'dropout_1': 0.042992410197569886, 'units_2': 176, 'dropout_2': 0.07761415249228693, 'units_3': 57, 'dropout_3': 0.28667927220167305, 'learning_rate': 0.00023079678828630702}. Best is trial 6 with value: 6142.8759765625.
# [I 2023-08-22 00:13:13,850] Trial 7 finished with value: 5802.7529296875 and parameters: {'batch_size': 256, 'units_1': 180, 'dropout_1': 0.20903509598770237, 'units_2': 105, 'dropout_2': 0.23268518165387586, 'units_3': 35, 'dropout_3': 0.27002277715486994, 'learning_rate': 0.0020007183330145624}. Best is trial 7 with value: 5802.7529296875.
# [I 2023-08-22 00:13:43,653] Trial 8 finished with value: 91152.5859375 and parameters: {'batch_size': 512, 'units_1': 130, 'dropout_1': 0.2241995754315536, 'units_2': 208, 'dropout_2': 0.035345478899816596, 'units_3': 92, 'dropout_3': 0.4770048408076922, 'learning_rate': 2.5543377207399166e-06}. Best is trial 7 with value: 5802.7529296875.
# [I 2023-08-22 00:14:22,719] Trial 9 finished with value: 84663.3359375 and parameters: {'batch_size': 512, 'units_1': 416, 'dropout_1': 0.07449387605398033, 'units_2': 129, 'dropout_2': 0.27148323081696757, 'units_3': 97, 'dropout_3': 0.20882686749689022, 'learning_rate': 3.0363513341173504e-05}. Best is trial 7 with value: 5802.7529296875.
# [I 2023-08-22 00:14:54,763] Trial 10 finished with value: 6373.48193359375 and parameters: {'batch_size': 256, 'units_1': 264, 'dropout_1': 0.0012029460313841, 'units_2': 69, 'dropout_2': 0.36354136878723375, 'units_3': 32, 'dropout_3': 0.3832062972445919, 'learning_rate': 0.03577589271922689}. Best is trial 7 with value: 5802.7529296875.
# [I 2023-08-22 00:15:40,559] Trial 11 finished with value: 5856.58740234375 and parameters: {'batch_size': 256, 'units_1': 365, 'dropout_1': 0.1363405731812282, 'units_2': 238, 'dropout_2': 0.1427179711479607, 'units_3': 57, 'dropout_3': 0.3154300434796147, 'learning_rate': 0.0031430033401915317}. Best is trial 7 with value: 5802.7529296875.
# [I 2023-08-22 00:16:35,183] Trial 12 finished with value: 5824.4560546875 and parameters: {'batch_size': 256, 'units_1': 376, 'dropout_1': 0.1253607493685006, 'units_2': 253, 'dropout_2': 0.15414671489296677, 'units_3': 50, 'dropout_3': 0.3554479304740271, 'learning_rate': 0.0030156811440459922}. Best is trial 7 with value: 5802.7529296875.
# [I 2023-08-22 00:17:20,845] Trial 13 finished with value: 5540.78125 and parameters: {'batch_size': 256, 'units_1': 411, 'dropout_1': 0.1665642242611643, 'units_2': 248, 'dropout_2': 0.1529642830518752, 'units_3': 50, 'dropout_3': 0.3703911612225602, 'learning_rate': 0.0038966960338289816}. Best is trial 13 with value: 5540.78125.
# [I 2023-08-22 00:17:57,739] Trial 14 finished with value: 6650.97314453125 and parameters: {'batch_size': 256, 'units_1': 443, 'dropout_1': 0.19619901140787283, 'units_2': 72, 'dropout_2': 0.1635602840114342, 'units_3': 48, 'dropout_3': 0.3796924533438847, 'learning_rate': 0.009997823396304069}. Best is trial 13 with value: 5540.78125.
# The best parameters are :
#  {'batch_size': 256, 'units_1': 411, 'dropout_1': 0.1665642242611643, 'units_2': 248, 'dropout_2': 0.1529642830518752, 'units_3': 50, 'dropout_3': 0.3703911612225602, 'learning_rate': 0.0038966960338289816}

# %% [markdown]
# ## 1.3.2. Rebuild the model

# %% [markdown]
# [Casual] The best parameters are : <br>
#  {'batch_size': 256, 'units_1': 442, 'dropout_1': 0.002595804557800896, 'units_2': 227, 'dropout_2': 0.08144365465161074, 'units_3': 53, 'dropout_3': 0.4993799244741601, 'learning_rate': 0.0006246220474456041}

# %%
# Define the model architecture
model_LSTM_c = Sequential([
    Dense(442, activation='relu', input_shape=(X_train_c.shape[1],)),
    Dropout(0.002595804557800896),
    BatchNormalization(),
    Dense(227, activation='relu'),
    Dropout(0.08144365465161074),
    BatchNormalization(),
    Dense(53, activation='relu'),
    Dropout(0.4993799244741601),
    BatchNormalization(),
    Dense(1)
])

# Compile the model
optimizer = Adam(learning_rate=0.0006246220474456041)
model_LSTM_c.compile(optimizer = optimizer, 
                   loss='mean_squared_error')

# Create a ModelCheckpoint callback to save the best model weights
checkpoint_c_n = ModelCheckpoint('best_model_c_weights.h5', 
                                  monitor='val_loss',  
                                  save_best_only=True,  
                                  mode='min', 
                                  verbose=1)

# Fit the model to the training data
model_LSTM_c.fit(X_train_c, y_train_c, 
               epochs=100, 
               batch_size=256, 
               validation_data=(X_valid_c, y_valid_c),
               callbacks=[checkpoint_c_n])
# Out:
# Epoch 1/100
# 47/51 [==========================>...] - ETA: 0s - loss: 3046.9211
# Epoch 1: val_loss improved from inf to 6804.77686, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 4s 21ms/step - loss: 3011.0500 - val_loss: 6804.7769
# Epoch 2/100
#  5/51 [=>............................] - ETA: 0s - loss: 2971.7854
# c:\Users\User\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 48/51 [===========================>..] - ETA: 0s - loss: 2760.6365
# Epoch 2: val_loss improved from 6804.77686 to 6737.84863, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 19ms/step - loss: 2759.0786 - val_loss: 6737.8486
# Epoch 3/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2603.4526
# Epoch 3: val_loss improved from 6737.84863 to 6516.14990, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 25ms/step - loss: 2592.4805 - val_loss: 6516.1499
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 2427.9922
# Epoch 4: val_loss improved from 6516.14990 to 6175.58984, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 2s 34ms/step - loss: 2427.9922 - val_loss: 6175.5898
# Epoch 5/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2246.5288
# Epoch 5: val_loss improved from 6175.58984 to 5688.40967, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 22ms/step - loss: 2255.9912 - val_loss: 5688.4097
# Epoch 6/100
# 50/51 [============================>.] - ETA: 0s - loss: 2084.2930
# Epoch 6: val_loss improved from 5688.40967 to 5178.20508, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 24ms/step - loss: 2087.0159 - val_loss: 5178.2051
# Epoch 7/100
# 50/51 [============================>.] - ETA: 0s - loss: 1911.8873
# Epoch 7: val_loss improved from 5178.20508 to 4407.91113, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 25ms/step - loss: 1909.9247 - val_loss: 4407.9111
# Epoch 8/100
# 50/51 [============================>.] - ETA: 0s - loss: 1730.6678
# Epoch 8: val_loss improved from 4407.91113 to 3974.92749, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 23ms/step - loss: 1728.7114 - val_loss: 3974.9275
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 1557.4500
# Epoch 9: val_loss improved from 3974.92749 to 3326.70337, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 23ms/step - loss: 1557.4500 - val_loss: 3326.7034
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 1389.7694
# Epoch 10: val_loss improved from 3326.70337 to 3112.26611, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 19ms/step - loss: 1389.7694 - val_loss: 3112.2661
# Epoch 11/100
# 50/51 [============================>.] - ETA: 0s - loss: 1220.2706
# Epoch 11: val_loss improved from 3112.26611 to 2456.52905, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 20ms/step - loss: 1223.0498 - val_loss: 2456.5291
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 1087.9855
# Epoch 12: val_loss improved from 2456.52905 to 2431.08154, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 22ms/step - loss: 1087.9855 - val_loss: 2431.0815
# Epoch 13/100
# 50/51 [============================>.] - ETA: 0s - loss: 958.4832
# Epoch 13: val_loss improved from 2431.08154 to 1904.57922, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 22ms/step - loss: 956.3512 - val_loss: 1904.5792
# Epoch 14/100
# 50/51 [============================>.] - ETA: 0s - loss: 832.0776
# Epoch 14: val_loss improved from 1904.57922 to 1833.12769, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 26ms/step - loss: 834.1201 - val_loss: 1833.1277
# Epoch 15/100
# 49/51 [===========================>..] - ETA: 0s - loss: 719.1869
# Epoch 15: val_loss improved from 1833.12769 to 1365.52771, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 20ms/step - loss: 717.7173 - val_loss: 1365.5277
# Epoch 16/100
# 48/51 [===========================>..] - ETA: 0s - loss: 624.4208
# Epoch 16: val_loss did not improve from 1365.52771
# 51/51 [==============================] - 1s 22ms/step - loss: 639.1262 - val_loss: 1621.3131
# Epoch 17/100
# 50/51 [============================>.] - ETA: 0s - loss: 555.2247
# Epoch 17: val_loss improved from 1365.52771 to 1345.68030, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 22ms/step - loss: 558.8754 - val_loss: 1345.6803
# Epoch 18/100
# 50/51 [============================>.] - ETA: 0s - loss: 499.4490
# Epoch 18: val_loss did not improve from 1345.68030
# 51/51 [==============================] - 1s 17ms/step - loss: 496.8706 - val_loss: 1496.6678
# Epoch 19/100
# 50/51 [============================>.] - ETA: 0s - loss: 460.7895
# Epoch 19: val_loss improved from 1345.68030 to 1276.21985, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 18ms/step - loss: 456.9024 - val_loss: 1276.2198
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 425.5273
# Epoch 20: val_loss improved from 1276.21985 to 963.11536, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 17ms/step - loss: 425.5273 - val_loss: 963.1154
# Epoch 21/100
# 48/51 [===========================>..] - ETA: 0s - loss: 402.8694
# Epoch 21: val_loss did not improve from 963.11536
# 51/51 [==============================] - 1s 15ms/step - loss: 395.9159 - val_loss: 1198.6725
# Epoch 22/100
# 50/51 [============================>.] - ETA: 0s - loss: 355.8138
# Epoch 22: val_loss did not improve from 963.11536
# 51/51 [==============================] - 1s 20ms/step - loss: 353.4503 - val_loss: 1029.0474
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 358.9851
# Epoch 23: val_loss did not improve from 963.11536
# 51/51 [==============================] - 1s 25ms/step - loss: 358.9851 - val_loss: 1178.9609
# Epoch 24/100
# 48/51 [===========================>..] - ETA: 0s - loss: 332.3609
# Epoch 24: val_loss improved from 963.11536 to 901.36603, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 18ms/step - loss: 335.6242 - val_loss: 901.3660
# Epoch 25/100
# 48/51 [===========================>..] - ETA: 0s - loss: 317.4152
# Epoch 25: val_loss improved from 901.36603 to 870.26642, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 17ms/step - loss: 319.4615 - val_loss: 870.2664
# Epoch 26/100
# 50/51 [============================>.] - ETA: 0s - loss: 303.4732
# Epoch 26: val_loss improved from 870.26642 to 811.68799, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 20ms/step - loss: 310.4726 - val_loss: 811.6880
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 309.4361
# Epoch 27: val_loss did not improve from 811.68799
# 51/51 [==============================] - 1s 17ms/step - loss: 309.4361 - val_loss: 1168.7467
# Epoch 28/100
# 50/51 [============================>.] - ETA: 0s - loss: 299.9538
# Epoch 28: val_loss did not improve from 811.68799
# 51/51 [==============================] - 1s 28ms/step - loss: 300.3366 - val_loss: 945.8327
# Epoch 29/100
# 48/51 [===========================>..] - ETA: 0s - loss: 296.7125
# Epoch 29: val_loss did not improve from 811.68799
# 51/51 [==============================] - 1s 17ms/step - loss: 293.4245 - val_loss: 900.6003
# Epoch 30/100
# 49/51 [===========================>..] - ETA: 0s - loss: 299.3126
# Epoch 30: val_loss did not improve from 811.68799
# 51/51 [==============================] - 2s 31ms/step - loss: 298.9525 - val_loss: 1189.4070
# Epoch 31/100
# 48/51 [===========================>..] - ETA: 0s - loss: 295.3807
# Epoch 31: val_loss did not improve from 811.68799
# 51/51 [==============================] - 1s 19ms/step - loss: 294.9893 - val_loss: 1075.4474
# Epoch 32/100
# 50/51 [============================>.] - ETA: 0s - loss: 300.2274
# Epoch 32: val_loss did not improve from 811.68799
# 51/51 [==============================] - 1s 23ms/step - loss: 299.1365 - val_loss: 982.5109
# Epoch 33/100
# 50/51 [============================>.] - ETA: 0s - loss: 283.0662
# Epoch 33: val_loss improved from 811.68799 to 753.80432, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 18ms/step - loss: 283.5806 - val_loss: 753.8043
# Epoch 34/100
# 50/51 [============================>.] - ETA: 0s - loss: 276.3799
# Epoch 34: val_loss did not improve from 753.80432
# 51/51 [==============================] - 1s 20ms/step - loss: 276.0670 - val_loss: 905.3690
# Epoch 35/100
# 49/51 [===========================>..] - ETA: 0s - loss: 285.8802
# Epoch 35: val_loss did not improve from 753.80432
# 51/51 [==============================] - 1s 23ms/step - loss: 284.0224 - val_loss: 936.1244
# Epoch 36/100
# 50/51 [============================>.] - ETA: 0s - loss: 286.5440
# Epoch 36: val_loss did not improve from 753.80432
# 51/51 [==============================] - 2s 31ms/step - loss: 286.7717 - val_loss: 877.6973
# Epoch 37/100
# 50/51 [============================>.] - ETA: 0s - loss: 275.1856
# Epoch 37: val_loss did not improve from 753.80432
# 51/51 [==============================] - 1s 24ms/step - loss: 277.0281 - val_loss: 1275.5557
# Epoch 38/100
# 48/51 [===========================>..] - ETA: 0s - loss: 263.2506
# Epoch 38: val_loss did not improve from 753.80432
# 51/51 [==============================] - 1s 24ms/step - loss: 262.4066 - val_loss: 839.3123
# Epoch 39/100
# 49/51 [===========================>..] - ETA: 0s - loss: 269.5019
# Epoch 39: val_loss did not improve from 753.80432
# 51/51 [==============================] - 1s 18ms/step - loss: 269.6387 - val_loss: 961.8824
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 259.4359
# Epoch 40: val_loss did not improve from 753.80432
# 51/51 [==============================] - 1s 16ms/step - loss: 259.4359 - val_loss: 864.7050
# Epoch 41/100
# 48/51 [===========================>..] - ETA: 0s - loss: 266.2728
# Epoch 41: val_loss did not improve from 753.80432
# 51/51 [==============================] - 1s 16ms/step - loss: 265.5190 - val_loss: 1006.2886
# Epoch 42/100
# 48/51 [===========================>..] - ETA: 0s - loss: 278.4032
# Epoch 42: val_loss improved from 753.80432 to 722.15491, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 19ms/step - loss: 276.7961 - val_loss: 722.1549
# Epoch 43/100
# 50/51 [============================>.] - ETA: 0s - loss: 265.1407
# Epoch 43: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 22ms/step - loss: 264.6130 - val_loss: 838.5381
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 262.4879
# Epoch 44: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 19ms/step - loss: 262.4879 - val_loss: 724.4742
# Epoch 45/100
# 50/51 [============================>.] - ETA: 0s - loss: 273.1314
# Epoch 45: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 27ms/step - loss: 271.4293 - val_loss: 920.3828
# Epoch 46/100
# 50/51 [============================>.] - ETA: 0s - loss: 269.8195
# Epoch 46: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 26ms/step - loss: 269.2525 - val_loss: 830.1312
# Epoch 47/100
# 49/51 [===========================>..] - ETA: 0s - loss: 264.8924
# Epoch 47: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 22ms/step - loss: 263.4586 - val_loss: 768.6827
# Epoch 48/100
# 49/51 [===========================>..] - ETA: 0s - loss: 270.2146
# Epoch 48: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 275.5158 - val_loss: 788.8281
# Epoch 49/100
# 48/51 [===========================>..] - ETA: 0s - loss: 252.9232
# Epoch 49: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 16ms/step - loss: 254.1500 - val_loss: 825.0133
# Epoch 50/100
# 49/51 [===========================>..] - ETA: 0s - loss: 249.6855
# Epoch 50: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 251.5651 - val_loss: 936.5851
# Epoch 51/100
# 49/51 [===========================>..] - ETA: 0s - loss: 247.9794
# Epoch 51: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 19ms/step - loss: 248.0878 - val_loss: 1054.5101
# Epoch 52/100
# 48/51 [===========================>..] - ETA: 0s - loss: 253.8608
# Epoch 52: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 255.6474 - val_loss: 918.3496
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 252.0567
# Epoch 53: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 16ms/step - loss: 252.0567 - val_loss: 841.6793
# Epoch 54/100
# 48/51 [===========================>..] - ETA: 0s - loss: 257.6741
# Epoch 54: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 256.2075 - val_loss: 1024.9695
# Epoch 55/100
# 49/51 [===========================>..] - ETA: 0s - loss: 253.4750
# Epoch 55: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 19ms/step - loss: 251.8266 - val_loss: 838.4816
# Epoch 56/100
# 49/51 [===========================>..] - ETA: 0s - loss: 255.6496
# Epoch 56: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 15ms/step - loss: 256.5495 - val_loss: 928.7037
# Epoch 57/100
# 50/51 [============================>.] - ETA: 0s - loss: 247.2247
# Epoch 57: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 246.5033 - val_loss: 885.1403
# Epoch 58/100
# 50/51 [============================>.] - ETA: 0s - loss: 243.2962
# Epoch 58: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 16ms/step - loss: 242.6370 - val_loss: 748.3137
# Epoch 59/100
# 50/51 [============================>.] - ETA: 0s - loss: 245.3380
# Epoch 59: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 22ms/step - loss: 245.0881 - val_loss: 1018.7935
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 260.5702
# Epoch 60: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 260.5702 - val_loss: 777.3586
# Epoch 61/100
# 49/51 [===========================>..] - ETA: 0s - loss: 242.7501
# Epoch 61: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 243.2979 - val_loss: 815.9684
# Epoch 62/100
# 48/51 [===========================>..] - ETA: 0s - loss: 258.3946
# Epoch 62: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 257.0281 - val_loss: 835.1450
# Epoch 63/100
# 49/51 [===========================>..] - ETA: 0s - loss: 246.7629
# Epoch 63: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 20ms/step - loss: 250.4485 - val_loss: 928.6949
# Epoch 64/100
# 48/51 [===========================>..] - ETA: 0s - loss: 239.6672
# Epoch 64: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 16ms/step - loss: 240.1994 - val_loss: 781.0944
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 260.9493
# Epoch 65: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 260.9493 - val_loss: 768.4305
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 258.7832
# Epoch 66: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 17ms/step - loss: 258.7832 - val_loss: 774.4528
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 239.6861
# Epoch 67: val_loss did not improve from 722.15491
# 51/51 [==============================] - 1s 20ms/step - loss: 239.6861 - val_loss: 868.0776
# Epoch 68/100
# 50/51 [============================>.] - ETA: 0s - loss: 230.1717
# Epoch 68: val_loss improved from 722.15491 to 720.45428, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 18ms/step - loss: 230.7177 - val_loss: 720.4543
# Epoch 69/100
# 48/51 [===========================>..] - ETA: 0s - loss: 240.1412
# Epoch 69: val_loss did not improve from 720.45428
# 51/51 [==============================] - 1s 16ms/step - loss: 240.4890 - val_loss: 854.6962
# Epoch 70/100
# 49/51 [===========================>..] - ETA: 0s - loss: 238.5898
# Epoch 70: val_loss did not improve from 720.45428
# 51/51 [==============================] - 1s 22ms/step - loss: 237.5305 - val_loss: 744.2201
# Epoch 71/100
# 50/51 [============================>.] - ETA: 0s - loss: 233.6167
# Epoch 71: val_loss did not improve from 720.45428
# 51/51 [==============================] - 2s 30ms/step - loss: 234.0392 - val_loss: 740.5374
# Epoch 72/100
# 48/51 [===========================>..] - ETA: 0s - loss: 230.1991
# Epoch 72: val_loss did not improve from 720.45428
# 51/51 [==============================] - 1s 21ms/step - loss: 231.6201 - val_loss: 865.7964
# Epoch 73/100
# 50/51 [============================>.] - ETA: 0s - loss: 241.4613
# Epoch 73: val_loss did not improve from 720.45428
# 51/51 [==============================] - 1s 20ms/step - loss: 240.4401 - val_loss: 786.4041
# Epoch 74/100
# 50/51 [============================>.] - ETA: 0s - loss: 229.2115
# Epoch 74: val_loss did not improve from 720.45428
# 51/51 [==============================] - 1s 19ms/step - loss: 231.3811 - val_loss: 1115.2649
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 246.2258
# Epoch 75: val_loss did not improve from 720.45428
# 51/51 [==============================] - 1s 19ms/step - loss: 246.2258 - val_loss: 857.3980
# Epoch 76/100
# 50/51 [============================>.] - ETA: 0s - loss: 246.9280
# Epoch 76: val_loss improved from 720.45428 to 671.98871, saving model to best_model_c_weights.h5
# 51/51 [==============================] - 1s 18ms/step - loss: 246.2749 - val_loss: 671.9887
# Epoch 77/100
# 49/51 [===========================>..] - ETA: 0s - loss: 235.6876
# Epoch 77: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 18ms/step - loss: 235.4347 - val_loss: 789.5915
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 259.0295
# Epoch 78: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 24ms/step - loss: 259.0295 - val_loss: 1027.9166
# Epoch 79/100
# 49/51 [===========================>..] - ETA: 0s - loss: 243.1299
# Epoch 79: val_loss did not improve from 671.98871
# 51/51 [==============================] - 2s 32ms/step - loss: 244.6565 - val_loss: 880.7648
# Epoch 80/100
# 48/51 [===========================>..] - ETA: 0s - loss: 234.1899
# Epoch 80: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 19ms/step - loss: 234.6509 - val_loss: 807.1723
# Epoch 81/100
# 50/51 [============================>.] - ETA: 0s - loss: 252.7105
# Epoch 81: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 23ms/step - loss: 251.9552 - val_loss: 778.1713
# Epoch 82/100
# 48/51 [===========================>..] - ETA: 0s - loss: 253.7917
# Epoch 82: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 21ms/step - loss: 251.3492 - val_loss: 933.9538
# Epoch 83/100
# 48/51 [===========================>..] - ETA: 0s - loss: 238.6610
# Epoch 83: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 15ms/step - loss: 240.6684 - val_loss: 870.9841
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 233.3545
# Epoch 84: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 16ms/step - loss: 233.3545 - val_loss: 752.4230
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 249.1658
# Epoch 85: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 16ms/step - loss: 249.1658 - val_loss: 726.1301
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 233.6574
# Epoch 86: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 20ms/step - loss: 233.6574 - val_loss: 842.7775
# Epoch 87/100
# 48/51 [===========================>..] - ETA: 0s - loss: 238.2736
# Epoch 87: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 18ms/step - loss: 238.4205 - val_loss: 945.4337
# Epoch 88/100
# 50/51 [============================>.] - ETA: 0s - loss: 238.2081
# Epoch 88: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 16ms/step - loss: 236.9394 - val_loss: 775.1580
# Epoch 89/100
# 48/51 [===========================>..] - ETA: 0s - loss: 241.6189
# Epoch 89: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 17ms/step - loss: 241.7147 - val_loss: 768.1637
# Epoch 90/100
# 50/51 [============================>.] - ETA: 0s - loss: 241.1404
# Epoch 90: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 20ms/step - loss: 241.6866 - val_loss: 884.3043
# Epoch 91/100
# 49/51 [===========================>..] - ETA: 0s - loss: 234.7737
# Epoch 91: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 18ms/step - loss: 237.0752 - val_loss: 843.4186
# Epoch 92/100
# 48/51 [===========================>..] - ETA: 0s - loss: 235.2544
# Epoch 92: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 16ms/step - loss: 234.1888 - val_loss: 859.8899
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 236.1194
# Epoch 93: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 16ms/step - loss: 236.1194 - val_loss: 941.3099
# Epoch 94/100
# 50/51 [============================>.] - ETA: 0s - loss: 228.7807
# Epoch 94: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 19ms/step - loss: 227.9281 - val_loss: 785.6600
# Epoch 95/100
# 49/51 [===========================>..] - ETA: 0s - loss: 223.6581
# Epoch 95: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 16ms/step - loss: 224.2140 - val_loss: 842.5675
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 246.3169
# Epoch 96: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 17ms/step - loss: 246.3169 - val_loss: 720.7701
# Epoch 97/100
# 50/51 [============================>.] - ETA: 0s - loss: 233.1671
# Epoch 97: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 16ms/step - loss: 233.6950 - val_loss: 936.0219
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 228.9745
# Epoch 98: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 20ms/step - loss: 228.9745 - val_loss: 921.5988
# Epoch 99/100
# 50/51 [============================>.] - ETA: 0s - loss: 216.7603
# Epoch 99: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 16ms/step - loss: 215.6143 - val_loss: 711.9764
# Epoch 100/100
# 50/51 [============================>.] - ETA: 0s - loss: 243.7944
# Epoch 100: val_loss did not improve from 671.98871
# 51/51 [==============================] - 1s 17ms/step - loss: 242.3938 - val_loss: 815.1136

# %%
# prediction
train_c_pred = model_LSTM_c.predict(X_train_c.values)
valid_c_pred = model_LSTM_c.predict(X_valid_c.values)
test_c_pred = model_LSTM_c.predict(X_test_c.values)

# predicted result
train_c_MAPE_lstm = mean_absolute_percentage_error(y_train_c, train_c_pred)
valid_c_MAPE_lstm = mean_absolute_percentage_error(y_valid_c, valid_c_pred)
test_c_MAPE_lstm = mean_absolute_percentage_error(y_test_c, test_c_pred)

print('train(casual) MAPE: ', train_c_MAPE_lstm)
print('valid(casual) MAPE: ', valid_c_MAPE_lstm)
print('test(casual) MAPE: ', test_c_MAPE_lstm)
# Out:
# 407/407 [==============================] - 1s 2ms/step
# 69/69 [==============================] - 0s 2ms/step
# 68/68 [==============================] - 0s 2ms/step
# train(casual) MAPE:  1142662991263142.8
# valid(casual) MAPE:  626486735866658.0
# test(casual) MAPE:  947756690934977.2

# %% [markdown]
# [Registered] The best parameters are : <br>
#  {'batch_size': 256, 'units_1': 411, 'dropout_1': 0.1665642242611643, 'units_2': 248, 'dropout_2': 0.1529642830518752, 'units_3': 50, 'dropout_3': 0.3703911612225602, 'learning_rate': 0.0038966960338289816}

# %%
# Define the model architecture
model_LSTM_r = Sequential([
    Dense(411, activation='relu', input_shape=(X_train_r.shape[1],)),
    Dropout(0.1665642242611643),
    BatchNormalization(),
    Dense(248, activation='relu'),
    Dropout(0.1529642830518752),
    BatchNormalization(),
    Dense(50, activation='relu'),
    Dropout(0.3703911612225602),
    BatchNormalization(),
    Dense(1)
])

# Compile the model
optimizer = Adam(learning_rate=0.0038966960338289816)
model_LSTM_r.compile(optimizer = optimizer, 
                   loss='mean_squared_error')


# Create a ModelCheckpoint callback to save the best model weights
checkpoint_r_n = ModelCheckpoint('best_model_r_weights.h5', 
                                  monitor='val_loss',  
                                  save_best_only=True,  
                                  mode='min', 
                                  verbose=1)

# Fit the model to the training data
model_LSTM_r.fit(X_train_r, y_train_r, 
               epochs=100, 
               batch_size=256, 
               validation_data=(X_valid_r, y_valid_r),
               callbacks = [checkpoint_r_n])
# Out:
# Epoch 1/100
# 49/51 [===========================>..] - ETA: 0s - loss: 34090.0273
# Epoch 1: val_loss improved from inf to 89198.28906, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 4s 22ms/step - loss: 33865.7773 - val_loss: 89198.2891
# Epoch 2/100
#  4/51 [=>............................] - ETA: 0s - loss: 31050.8086
# c:\Users\User\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 51/51 [==============================] - ETA: 0s - loss: 29657.0059
# Epoch 2: val_loss improved from 89198.28906 to 78709.07031, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 26ms/step - loss: 29657.0059 - val_loss: 78709.0703
# Epoch 3/100
# 48/51 [===========================>..] - ETA: 0s - loss: 23397.0684
# Epoch 3: val_loss improved from 78709.07031 to 71771.76562, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 19ms/step - loss: 23322.5391 - val_loss: 71771.7656
# Epoch 4/100
# 50/51 [============================>.] - ETA: 0s - loss: 16328.7012
# Epoch 4: val_loss improved from 71771.76562 to 60540.82031, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 29ms/step - loss: 16309.2422 - val_loss: 60540.8203
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 10452.2686
# Epoch 5: val_loss improved from 60540.82031 to 34709.29688, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 22ms/step - loss: 10452.2686 - val_loss: 34709.2969
# Epoch 6/100
# 48/51 [===========================>..] - ETA: 0s - loss: 7015.4644
# Epoch 6: val_loss improved from 34709.29688 to 17984.71289, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 18ms/step - loss: 6988.8657 - val_loss: 17984.7129
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 5326.6460
# Epoch 7: val_loss did not improve from 17984.71289
# 51/51 [==============================] - 1s 28ms/step - loss: 5326.6460 - val_loss: 20949.8516
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 5055.9751
# Epoch 8: val_loss improved from 17984.71289 to 15752.76270, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 20ms/step - loss: 5055.9751 - val_loss: 15752.7627
# Epoch 9/100
# 48/51 [===========================>..] - ETA: 0s - loss: 4765.0952
# Epoch 9: val_loss did not improve from 15752.76270
# 51/51 [==============================] - 1s 20ms/step - loss: 4731.7178 - val_loss: 20397.6621
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 4103.7554
# Epoch 10: val_loss did not improve from 15752.76270
# 51/51 [==============================] - 1s 26ms/step - loss: 4103.7554 - val_loss: 23552.5137
# Epoch 11/100
# 50/51 [============================>.] - ETA: 0s - loss: 4107.4258
# Epoch 11: val_loss did not improve from 15752.76270
# 51/51 [==============================] - 1s 22ms/step - loss: 4093.7532 - val_loss: 20826.5859
# Epoch 12/100
# 48/51 [===========================>..] - ETA: 0s - loss: 4097.7695
# Epoch 12: val_loss did not improve from 15752.76270
# 51/51 [==============================] - 1s 21ms/step - loss: 4068.2305 - val_loss: 20603.2285
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 3733.9282
# Epoch 13: val_loss improved from 15752.76270 to 11103.84375, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 16ms/step - loss: 3733.9282 - val_loss: 11103.8438
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 3777.2849
# Epoch 14: val_loss did not improve from 11103.84375
# 51/51 [==============================] - 1s 16ms/step - loss: 3777.2849 - val_loss: 17668.8105
# Epoch 15/100
# 50/51 [============================>.] - ETA: 0s - loss: 3791.5967
# Epoch 15: val_loss did not improve from 11103.84375
# 51/51 [==============================] - 1s 23ms/step - loss: 3797.7725 - val_loss: 15043.4062
# Epoch 16/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3656.1851
# Epoch 16: val_loss did not improve from 11103.84375
# 51/51 [==============================] - 1s 25ms/step - loss: 3658.8667 - val_loss: 20811.4062
# Epoch 17/100
# 48/51 [===========================>..] - ETA: 0s - loss: 3985.1523
# Epoch 17: val_loss improved from 11103.84375 to 7900.33691, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 29ms/step - loss: 4022.5291 - val_loss: 7900.3369
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 3725.2114
# Epoch 18: val_loss did not improve from 7900.33691
# 51/51 [==============================] - 1s 17ms/step - loss: 3725.2114 - val_loss: 10999.1572
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 3516.9297
# Epoch 19: val_loss did not improve from 7900.33691
# 51/51 [==============================] - 2s 40ms/step - loss: 3516.9297 - val_loss: 8658.0674
# Epoch 20/100
# 50/51 [============================>.] - ETA: 0s - loss: 3551.8506
# Epoch 20: val_loss did not improve from 7900.33691
# 51/51 [==============================] - 2s 36ms/step - loss: 3540.9832 - val_loss: 22158.2676
# Epoch 21/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3717.4165
# Epoch 21: val_loss improved from 7900.33691 to 7716.16016, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 25ms/step - loss: 3691.0496 - val_loss: 7716.1602
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 3209.6658
# Epoch 22: val_loss did not improve from 7716.16016
# 51/51 [==============================] - 2s 35ms/step - loss: 3209.6658 - val_loss: 15006.0469
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 3428.9929
# Epoch 23: val_loss did not improve from 7716.16016
# 51/51 [==============================] - 1s 26ms/step - loss: 3428.9929 - val_loss: 7838.6460
# Epoch 24/100
# 50/51 [============================>.] - ETA: 0s - loss: 3639.8662
# Epoch 24: val_loss did not improve from 7716.16016
# 51/51 [==============================] - 1s 27ms/step - loss: 3636.9697 - val_loss: 9156.5684
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 3410.8738
# Epoch 25: val_loss did not improve from 7716.16016
# 51/51 [==============================] - 1s 25ms/step - loss: 3410.8738 - val_loss: 8750.6963
# Epoch 26/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3426.4868
# Epoch 26: val_loss did not improve from 7716.16016
# 51/51 [==============================] - 1s 21ms/step - loss: 3419.9229 - val_loss: 12902.5625
# Epoch 27/100
# 50/51 [============================>.] - ETA: 0s - loss: 3482.0498
# Epoch 27: val_loss did not improve from 7716.16016
# 51/51 [==============================] - 1s 21ms/step - loss: 3487.5327 - val_loss: 13851.4053
# Epoch 28/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3544.7122
# Epoch 28: val_loss did not improve from 7716.16016
# 51/51 [==============================] - 1s 26ms/step - loss: 3548.7632 - val_loss: 8233.6416
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 3221.0078
# Epoch 29: val_loss did not improve from 7716.16016
# 51/51 [==============================] - 1s 23ms/step - loss: 3221.0078 - val_loss: 9507.4014
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 3169.7793
# Epoch 30: val_loss improved from 7716.16016 to 7704.41211, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 23ms/step - loss: 3169.7793 - val_loss: 7704.4121
# Epoch 31/100
# 50/51 [============================>.] - ETA: 0s - loss: 3080.8474
# Epoch 31: val_loss improved from 7704.41211 to 6927.33789, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 18ms/step - loss: 3111.4673 - val_loss: 6927.3379
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 3068.5979
# Epoch 32: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 1s 22ms/step - loss: 3068.5979 - val_loss: 11586.9678
# Epoch 33/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2937.1511
# Epoch 33: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 1s 18ms/step - loss: 2910.5708 - val_loss: 9096.9121
# Epoch 34/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2993.4863
# Epoch 34: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 2s 30ms/step - loss: 2997.6646 - val_loss: 7783.5850
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 3233.0801
# Epoch 35: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 1s 26ms/step - loss: 3233.0801 - val_loss: 10396.2041
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 3011.6060
# Epoch 36: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 1s 23ms/step - loss: 3011.6060 - val_loss: 11567.9385
# Epoch 37/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3536.2979
# Epoch 37: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 1s 19ms/step - loss: 3541.8184 - val_loss: 13219.8750
# Epoch 38/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3222.7051
# Epoch 38: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 1s 17ms/step - loss: 3204.2063 - val_loss: 11001.6777
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 3032.5505
# Epoch 39: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 1s 16ms/step - loss: 3032.5505 - val_loss: 9153.2500
# Epoch 40/100
# 48/51 [===========================>..] - ETA: 0s - loss: 3084.4934
# Epoch 40: val_loss did not improve from 6927.33789
# 51/51 [==============================] - 1s 16ms/step - loss: 3105.0164 - val_loss: 11019.3730
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 3343.0046
# Epoch 41: val_loss improved from 6927.33789 to 6140.80615, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 23ms/step - loss: 3343.0046 - val_loss: 6140.8062
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 2990.8308
# Epoch 42: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 1s 17ms/step - loss: 2990.8308 - val_loss: 7311.5786
# Epoch 43/100
# 50/51 [============================>.] - ETA: 0s - loss: 3077.7937
# Epoch 43: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 1s 22ms/step - loss: 3075.0854 - val_loss: 9642.4941
# Epoch 44/100
# 50/51 [============================>.] - ETA: 0s - loss: 3135.9226
# Epoch 44: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 1s 20ms/step - loss: 3133.8953 - val_loss: 13021.3623
# Epoch 45/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3162.4185
# Epoch 45: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 2s 30ms/step - loss: 3192.5312 - val_loss: 12362.3389
# Epoch 46/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3062.7598
# Epoch 46: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 1s 20ms/step - loss: 3086.0325 - val_loss: 14112.4307
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 3088.2654
# Epoch 47: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 1s 23ms/step - loss: 3088.2654 - val_loss: 14868.1143
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 3453.4927
# Epoch 48: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 1s 24ms/step - loss: 3453.4927 - val_loss: 19610.6211
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 3176.7949
# Epoch 49: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 1s 24ms/step - loss: 3176.7949 - val_loss: 13492.0010
# Epoch 50/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3061.0437
# Epoch 50: val_loss did not improve from 6140.80615
# 51/51 [==============================] - 1s 20ms/step - loss: 3063.3555 - val_loss: 6306.2666
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 3111.7791
# Epoch 51: val_loss improved from 6140.80615 to 5818.08105, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 16ms/step - loss: 3111.7791 - val_loss: 5818.0811
# Epoch 52/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3230.5518
# Epoch 52: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 15ms/step - loss: 3239.3916 - val_loss: 7578.8301
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 3012.3926
# Epoch 53: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 24ms/step - loss: 3012.3926 - val_loss: 10302.0107
# Epoch 54/100
# 48/51 [===========================>..] - ETA: 0s - loss: 3339.4509
# Epoch 54: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 18ms/step - loss: 3318.6794 - val_loss: 7050.0874
# Epoch 55/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3009.8459
# Epoch 55: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 26ms/step - loss: 2992.8613 - val_loss: 6658.5938
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 3008.8223
# Epoch 56: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 17ms/step - loss: 3008.8223 - val_loss: 6729.2837
# Epoch 57/100
# 50/51 [============================>.] - ETA: 0s - loss: 2976.0823
# Epoch 57: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 2s 32ms/step - loss: 2967.1584 - val_loss: 6212.6094
# Epoch 58/100
# 50/51 [============================>.] - ETA: 0s - loss: 2812.4438
# Epoch 58: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 27ms/step - loss: 2824.3853 - val_loss: 5920.5278
# Epoch 59/100
# 50/51 [============================>.] - ETA: 0s - loss: 2791.0740
# Epoch 59: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 29ms/step - loss: 2795.5325 - val_loss: 8382.8750
# Epoch 60/100
# 49/51 [===========================>..] - ETA: 0s - loss: 3192.9844
# Epoch 60: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 22ms/step - loss: 3162.8525 - val_loss: 11109.1611
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 2956.4177
# Epoch 61: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 21ms/step - loss: 2956.4177 - val_loss: 7866.2544
# Epoch 62/100
# 48/51 [===========================>..] - ETA: 0s - loss: 2860.6003
# Epoch 62: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 16ms/step - loss: 2866.2356 - val_loss: 7649.1421
# Epoch 63/100
# 50/51 [============================>.] - ETA: 0s - loss: 2880.1013
# Epoch 63: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 16ms/step - loss: 2866.3547 - val_loss: 8670.9111
# Epoch 64/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2993.3835
# Epoch 64: val_loss did not improve from 5818.08105
# 51/51 [==============================] - 1s 15ms/step - loss: 2997.7581 - val_loss: 7391.9209
# Epoch 65/100
# 48/51 [===========================>..] - ETA: 0s - loss: 2834.4075
# Epoch 65: val_loss improved from 5818.08105 to 5288.88916, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 21ms/step - loss: 2819.0544 - val_loss: 5288.8892
# Epoch 66/100
# 50/51 [============================>.] - ETA: 0s - loss: 2727.9355
# Epoch 66: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 22ms/step - loss: 2719.1880 - val_loss: 8630.6484
# Epoch 67/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2882.1082
# Epoch 67: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 2s 31ms/step - loss: 2880.1038 - val_loss: 6600.1309
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 2847.2522
# Epoch 68: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 2s 48ms/step - loss: 2847.2522 - val_loss: 7791.2227
# Epoch 69/100
# 48/51 [===========================>..] - ETA: 0s - loss: 2754.7742
# Epoch 69: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 27ms/step - loss: 2773.2454 - val_loss: 6200.6948
# Epoch 70/100
# 50/51 [============================>.] - ETA: 0s - loss: 3027.6643
# Epoch 70: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 29ms/step - loss: 3014.1882 - val_loss: 6813.3589
# Epoch 71/100
# 50/51 [============================>.] - ETA: 0s - loss: 2862.3906
# Epoch 71: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 29ms/step - loss: 2861.5112 - val_loss: 5321.6509
# Epoch 72/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2768.9155
# Epoch 72: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 23ms/step - loss: 2778.7378 - val_loss: 7238.2666
# Epoch 73/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2772.3564
# Epoch 73: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 23ms/step - loss: 2788.8179 - val_loss: 7246.3721
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 2464.0876
# Epoch 74: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 24ms/step - loss: 2464.0876 - val_loss: 6296.6572
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 2762.7622
# Epoch 75: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 20ms/step - loss: 2762.7622 - val_loss: 7475.3735
# Epoch 76/100
# 48/51 [===========================>..] - ETA: 0s - loss: 2619.9219
# Epoch 76: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 20ms/step - loss: 2616.6089 - val_loss: 7794.0508
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 2798.3083
# Epoch 77: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 21ms/step - loss: 2798.3083 - val_loss: 7348.2402
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 2699.6826
# Epoch 78: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 23ms/step - loss: 2699.6826 - val_loss: 7096.6060
# Epoch 79/100
# 50/51 [============================>.] - ETA: 0s - loss: 2617.0093
# Epoch 79: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 21ms/step - loss: 2614.5527 - val_loss: 5439.5679
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 2583.3811
# Epoch 80: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 20ms/step - loss: 2583.3811 - val_loss: 6766.3296
# Epoch 81/100
# 50/51 [============================>.] - ETA: 0s - loss: 2693.3362
# Epoch 81: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 24ms/step - loss: 2694.4734 - val_loss: 9013.9346
# Epoch 82/100
# 50/51 [============================>.] - ETA: 0s - loss: 2601.6655
# Epoch 82: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 20ms/step - loss: 2601.6150 - val_loss: 9649.3047
# Epoch 83/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2800.5125
# Epoch 83: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 20ms/step - loss: 2781.4307 - val_loss: 7655.4077
# Epoch 84/100
# 50/51 [============================>.] - ETA: 0s - loss: 2682.2329
# Epoch 84: val_loss did not improve from 5288.88916
# 51/51 [==============================] - 1s 20ms/step - loss: 2679.5337 - val_loss: 8046.6104
# Epoch 85/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2457.6431
# Epoch 85: val_loss improved from 5288.88916 to 4835.04346, saving model to best_model_r_weights.h5
# 51/51 [==============================] - 1s 26ms/step - loss: 2458.5693 - val_loss: 4835.0435
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 2567.1257
# Epoch 86: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 21ms/step - loss: 2567.1257 - val_loss: 6406.5107
# Epoch 87/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2600.2944
# Epoch 87: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 23ms/step - loss: 2586.1250 - val_loss: 8267.5010
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 2630.3335
# Epoch 88: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 27ms/step - loss: 2630.3335 - val_loss: 7153.2144
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 2493.2310
# Epoch 89: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 23ms/step - loss: 2493.2310 - val_loss: 7396.9644
# Epoch 90/100
# 48/51 [===========================>..] - ETA: 0s - loss: 2546.1409
# Epoch 90: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 16ms/step - loss: 2548.0378 - val_loss: 5498.2959
# Epoch 91/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2384.1780
# Epoch 91: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 23ms/step - loss: 2377.7844 - val_loss: 6553.3115
# Epoch 92/100
# 50/51 [============================>.] - ETA: 0s - loss: 2608.2812
# Epoch 92: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 18ms/step - loss: 2608.6704 - val_loss: 6341.4727
# Epoch 93/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2766.0173
# Epoch 93: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 15ms/step - loss: 2765.3501 - val_loss: 5701.7646
# Epoch 94/100
# 50/51 [============================>.] - ETA: 0s - loss: 2510.9282
# Epoch 94: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 15ms/step - loss: 2512.1116 - val_loss: 7930.5327
# Epoch 95/100
# 48/51 [===========================>..] - ETA: 0s - loss: 2482.4224
# Epoch 95: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 16ms/step - loss: 2487.5190 - val_loss: 8198.9961
# Epoch 96/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2499.0320
# Epoch 96: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 20ms/step - loss: 2500.0073 - val_loss: 6378.0435
# Epoch 97/100
# 50/51 [============================>.] - ETA: 0s - loss: 2435.4409
# Epoch 97: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 20ms/step - loss: 2447.0950 - val_loss: 7608.4204
# Epoch 98/100
# 49/51 [===========================>..] - ETA: 0s - loss: 2374.3093
# Epoch 98: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 20ms/step - loss: 2365.2847 - val_loss: 6368.3242
# Epoch 99/100
# 50/51 [============================>.] - ETA: 0s - loss: 2397.8843
# Epoch 99: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 24ms/step - loss: 2411.0186 - val_loss: 6275.6548
# Epoch 100/100
# 50/51 [============================>.] - ETA: 0s - loss: 2508.5752
# Epoch 100: val_loss did not improve from 4835.04346
# 51/51 [==============================] - 1s 19ms/step - loss: 2499.0654 - val_loss: 8669.6387

# %%
# prediction
train_r_pred = model_LSTM_r.predict(X_train_r.values)
valid_r_pred = model_LSTM_r.predict(X_valid_r.values)
test_r_pred = model_LSTM_r.predict(X_test_r.values)

# predicted result
train_r_MAPE_lstm = mean_absolute_percentage_error(y_train_r, train_r_pred)
valid_r_MAPE_lstm = mean_absolute_percentage_error(y_valid_r, valid_r_pred)
test_r_MAPE_lstm = mean_absolute_percentage_error(y_test_r, test_r_pred)

print('train(registered) MAPE: ', train_r_MAPE_lstm)
print('valid(registered) MAPE: ', valid_r_MAPE_lstm)
print('test(registered) MAPE: ', test_r_MAPE_lstm)
# Out:
# 407/407 [==============================] - 1s 2ms/step
# 69/69 [==============================] - 0s 2ms/step
# 68/68 [==============================] - 0s 2ms/step
# train(registered) MAPE:  95373767308959.11
# valid(registered) MAPE:  0.45752723516030214
# test(registered) MAPE:  37357019332125.08

# %%
combined_result_train = y_train.copy()

combined_result_train = pd.DataFrame(combined_result_train).join(pd.DataFrame(train_c_pred, index = y_train.index))
combined_result_train = combined_result_train.rename(columns={'cnt': 'cnt', 0: 'casual_pred'})

combined_result_train = combined_result_train.join(pd.DataFrame(train_r_pred, index = y_train.index))
combined_result_train = combined_result_train.rename(columns={'cnt': 'cnt', 'casual_pred': 'casual_pred', 0: 'registered_pred'})

combined_result_train['cnt_pred'] = round(combined_result_train['casual_pred'] + combined_result_train['registered_pred'],0)

# %%
combined_result_valid = y_valid.copy()

combined_result_valid = pd.DataFrame(combined_result_valid).join(pd.DataFrame(valid_c_pred, index = y_valid.index))
combined_result_valid = combined_result_valid.rename(columns={'cnt': 'cnt', 0: 'casual_pred'})

combined_result_valid = combined_result_valid.join(pd.DataFrame(valid_r_pred, index = y_valid.index))
combined_result_valid = combined_result_valid.rename(columns={'cnt': 'cnt', 'casual_pred': 'casual_pred', 0: 'registered_pred'})

combined_result_valid['cnt_pred'] = round(combined_result_valid['casual_pred'] + combined_result_valid['registered_pred'],0)

# %%
combined_result_test = y_test.copy()

combined_result_test = pd.DataFrame(combined_result_test).join(pd.DataFrame(test_c_pred, index = y_test.index))
combined_result_test = combined_result_test.rename(columns={'cnt': 'cnt', 0: 'casual_pred'})

combined_result_test = combined_result_test.join(pd.DataFrame(test_r_pred, index = y_test.index))
combined_result_test = combined_result_test.rename(columns={'cnt': 'cnt', 'casual_pred': 'casual_pred', 0: 'registered_pred'})

combined_result_test['cnt_pred'] = round(combined_result_test['casual_pred'] + combined_result_test['registered_pred'],0)

# %%
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(y_train.index, y_train.values, label="actual(train dataset)", alpha = 0.5)
ax.plot(y_valid.index, y_valid.values, label="actual(test dataset)", alpha = 0.5)
ax.plot(y_test.index, y_test.values, label="actual(test dataset)", alpha = 0.5)

ax.plot(y_train.index, combined_result_train['cnt_pred'], linestyle="dotted", lw=2,color="m", alpha = 0.5)
ax.plot(y_valid.index, combined_result_valid['cnt_pred'], label="LSTM_valid", linestyle="dotted", lw=2, color="m", alpha = 0.5)
ax.plot(y_test.index, combined_result_test['cnt_pred'], label="LSTM_test", linestyle="dotted", lw=2, color="m", alpha = 0.5) 
plt.legend()

# %%
# predicted result
train_MAPE_lstm = mean_absolute_percentage_error(combined_result_train['cnt'], combined_result_train['cnt_pred'])
valid_MAPE_lstm = mean_absolute_percentage_error(combined_result_valid['cnt'], combined_result_valid['cnt_pred'])
test_MAPE_lstm = mean_absolute_percentage_error(combined_result_test['cnt'], combined_result_test['cnt_pred'])

print('train MAPE is {}'.format(train_MAPE_lstm))
print('valid MAPE is {}'.format(valid_MAPE_lstm))
print('test MAPE is {}'.format(test_MAPE_lstm))
# Out:
# train MAPE is 0.6792775151708926
# valid MAPE is 0.4529603351409747
# test MAPE is 0.6740810904952326

# %% [markdown]
# # Problem 5

# %% [markdown]
# ## 5.1.	EXPLORATORY DATA ANALYSIS: CONDUCT A PRELIMINARY ANALYSIS OF THE DATASET. VISUALIZE THE DATA AND REPORT ANY OBSERVATIONS THAT MIGHT BE RELEVANT TO YOUR TASK. (5 POINTS)

# %%
train_data = pd.read_csv('train_data.csv')
test_data = pd.read_csv('test_data.csv')

# %%
train_data.describe()
# Out:
#        travel_mode  TrvlTime_number          Age  indiv_trvl_frequency  \
# count  4000.000000      4000.000000  4000.000000           4000.000000
# mean      0.789750      1044.952107    45.013750             28.658250
# std       0.407537      1424.072973    14.929259             20.390105
# min       0.000000         6.000000    16.000000              3.000000
# 25%       1.000000       340.078000    34.000000             15.000000
# 50%       1.000000       660.000000    44.000000             24.000000
# 75%       1.000000      1318.000000    56.000000             36.000000
# max       1.000000     34350.000000    89.000000            192.000000
#
#              HHVeh       HHsize
# count  4000.000000  4000.000000
# mean      1.804000     3.695250
# std       0.910105     1.710733
# min       0.000000     1.000000
# 25%       1.000000     2.000000
# 50%       2.000000     4.000000
# 75%       2.000000     5.000000
# max       7.000000    13.000000

# %%
test_data.describe()
# Out:
#        travel_mode  TrvlTime_number          Age  indiv_trvl_frequency  \
# count  1000.000000      1000.000000  1000.000000           1000.000000
# mean      0.783000      1108.739891    44.355000             28.402000
# std       0.412409      1667.569592    14.577087             22.071782
# min       0.000000        19.999980    16.000000              3.000000
# 25%       1.000000       368.750000    33.000000             14.000000
# 50%       1.000000       699.008500    43.000000             22.000000
# 75%       1.000000      1370.890000    55.000000             35.250000
# max       1.000000     37764.000000    94.000000            192.000000
#
#              HHVeh       HHsize
# count  1000.000000  1000.000000
# mean      1.767000     3.601000
# std       0.949533     1.677681
# min       0.000000     1.000000
# 25%       1.000000     2.000000
# 50%       2.000000     4.000000
# 75%       2.000000     5.000000
# max       7.000000    12.000000

# %% [markdown]
# Overall statistics looks very similar which indicates a successful random sampling between train and test dataset.

# %%
train_data.dtypes
# Out:
# travel_mode               int64
# TrvlTime_number         float64
# Age                       int64
# indiv_trvl_frequency      int64
# HHVeh                     int64
# HHsize                    int64
# dtype: object

# %% [markdown]
# All of the columns are numeric and thus we can feed the data to pca model without preprocessing other types of data such as object or datetime.

# %%
train_data.hist(figsize = (10,10))
# Out:
# array([[<Axes: title={'center': 'travel_mode'}>,
#         <Axes: title={'center': 'TrvlTime_number'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'indiv_trvl_frequency'}>],
#        [<Axes: title={'center': 'HHVeh'}>,
#         <Axes: title={'center': 'HHsize'}>]], dtype=object)

# %% [markdown]
# There are reletively large gaps in scale of each variable.  Standardization would be necessary before conducting pca/clustering.

# %%
train_data.corr()
# Out:
#                       travel_mode  TrvlTime_number       Age  \
# travel_mode              1.000000         0.158679  0.104993
# TrvlTime_number          0.158679         1.000000  0.022430
# Age                      0.104993         0.022430  1.000000
# indiv_trvl_frequency     0.233447         0.007686 -0.004295
# HHVeh                    0.377664         0.108580  0.022688
# HHsize                   0.005274        -0.034190 -0.325799
#
#                       indiv_trvl_frequency     HHVeh    HHsize
# travel_mode                       0.233447  0.377664  0.005274
# TrvlTime_number                   0.007686  0.108580 -0.034190
# Age                              -0.004295  0.022688 -0.325799
# indiv_trvl_frequency              1.000000  0.594961  0.185159
# HHVeh                             0.594961  1.000000  0.180699
# HHsize                            0.185159  0.180699  1.000000

# %% [markdown]
# There are a few autocorrelated variables such as Age and HHsize, or HHVeh and infiv_trvl_frequency.  <br>
# This can be taken care of by conducting PCA before clustering.

# %% [markdown]
# ## 5.2.	DATA PREPROCESSING: STANDARDIZE THE DATASET AND USE PRINCIPAL COMPONENT ANALYSIS (PCA) TO REDUCE THE DIMENSIONALITY OF THE DATASET (PLEASE NOMINATE AN APPROPRIATE NUMBER OF PRINCIPAL COMPONENTS TO REPRESENT AT LEAST 90% VARIATION IN THE DATA). NOTE THAT THE DATASET IS ALREADY SPLIT INTO A TRAINING SET AND A TEST SET. YOU SHOULD USE THEM DIRECTLY. (5 POINTS)

# %% [markdown]
# ### 5.2.1. standardize the dataset

# %% [markdown]
# Introduce the standardize function which implements the following operations to the input dataframe(train_data or test_data)
# - change the df shape so it only includes the columns with independent variables
# - initiate StandardScaler and fit&transform the reshaped df
# - convert back the standardized arrays into pandas df
# - insert back the dependent variable (travel_mode) to the df
# - return df

# %%
def standardize(df):
    df_stmd = df.drop('travel_mode', axis = 1)
    scaler = StandardScaler()
    scaled_df = scaler.fit_transform(df_stmd)
    scaled_df = pd.DataFrame(scaled_df, columns = df_stmd.columns)
    scaled_df['travel_mode'] = df['travel_mode']
    scaled_df.insert(0, 'travel_mode', scaled_df.pop('travel_mode'))
    return scaled_df

# %% [markdown]
# apply standardize function to both data

# %%
train_data_std = standardize(train_data)
test_data_std = standardize(test_data)

# %% [markdown]
# check if the transformation was successful be looking at the head of df and look at mean and sd (whether they are around 0 and 1 respectively)

# %%
train_data_std.head(3)
# Out:
#    travel_mode  TrvlTime_number       Age  indiv_trvl_frequency     HHVeh  \
# 0            0         -0.61661  0.066070              1.243001  1.314298
# 1            1         -0.10180  0.133061             -0.228485  1.314298
# 2            1          0.13347 -0.469858             -0.424683  0.215387
#
#     HHsize
# 0  0.76278
# 1  0.76278
# 2  0.76278

# %%
train_data_std.describe()
# Out:
#        travel_mode  TrvlTime_number           Age  indiv_trvl_frequency  \
# count  4000.000000     4.000000e+03  4.000000e+03          4.000000e+03
# mean      0.789750     1.225686e-16 -1.065814e-16          6.217249e-17
# std       0.407537     1.000125e+00  1.000125e+00          1.000125e+00
# min       0.000000    -7.296550e-01 -1.943658e+00         -1.258525e+00
# 25%       1.000000    -4.950324e-01 -7.378214e-01         -6.699307e-01
# 50%       1.000000    -2.703515e-01 -6.791206e-02         -2.284850e-01
# 75%       1.000000     1.917613e-01  7.359792e-01          3.601094e-01
# max       1.000000     2.339010e+01  2.946680e+00          8.011836e+00
#
#               HHVeh        HHsize
# count  4.000000e+03  4.000000e+03
# mean  -4.884981e-17 -1.332268e-17
# std    1.000125e+00  1.000125e+00
# min   -1.982437e+00 -1.575691e+00
# 25%   -8.835250e-01 -9.910731e-01
# 50%    2.153867e-01  1.781622e-01
# 75%    2.153867e-01  7.627799e-01
# max    5.709945e+00  5.439721e+00

# %% [markdown]
# ### 5.2.2. Reduce dimension using PCA

# %% [markdown]
# Introduce the standardize function which implements the following operations to the input dataframe(train_data_std or test_data_std)
# 1. conducting PCA
# 2. Calculate the variance ratio of each PC
# 3. Drawing screeplot to visualize 2.
# 4. calculate the contribution of each PC towards the original variables
# 5. calculate the predicted result per PC, draw histogram and return data in dataframe format.

# %%
def executePCA(df):
    # conduct PCA
    df_pca = df.drop('travel_mode', axis = 1)
    pca = PCA(n_components = df_pca.shape[1])
    pca.fit(df_pca)
    pca_pred = pca.transform(df_pca)

    # calculate the variance ratio of each PC
    variance_ratio = [round(variance_ratio, 5) for variance_ratio in pca.explained_variance_ratio_]
    print('variance_ratio of each PC:', variance_ratio)

    # scree plot
    plt.figure()
    plt.figure()
    plt.plot([0] + list(range(1, len(variance_ratio) + 1)), [0] + list(np.cumsum(pca.explained_variance_ratio_)))
    plt.hlines(y = 0.90, xmin = 0, xmax = len(variance_ratio) , color = 'r', linewidth = 0.7)
    plt.xlabel('Principal Component')
    plt.ylabel('Cumulative Explained Variance Ratio')
    plt.title('Scree Plot')
    plt.grid(True)
    plt.show()

    # contribution by PC
    contribution = pd.DataFrame(pca.components_)
    PCindex = ['PC' + str(i + 1) for i in range(df_pca.shape[1])]
    contribution.index = PCindex
    contribution.columns = [df_pca.columns[0:]]
    print(contribution)

    # predition
    pca_pred_df = pd.DataFrame(pca_pred,
                           columns = ["PC{}".format(x + 1) for x in range(len(df_pca.columns))]
                           )
    
    # draw histogram
    pca_pred_df.hist(figsize = (8,7))
    
    return pca_pred_df

# %% [markdown]
# Conduct PCA for train data

# %%
pca_pred_train = executePCA(train_data_std)
# Out:
# variance_ratio of each PC: [0.34276, 0.2539, 0.19762, 0.12658, 0.07914]
#     TrvlTime_number       Age indiv_trvl_frequency     HHVeh    HHsize
# PC1        0.079706 -0.161969             0.635794  0.637249  0.396350
# PC2        0.246739  0.711544             0.221017  0.274890 -0.555349
# PC3        0.956332 -0.218188            -0.183350 -0.028408  0.058308
# PC4        0.062927  0.646430            -0.193496 -0.103336  0.728045
# PC5        0.119319  0.044639             0.689826 -0.711944  0.032340

# %% [markdown]
# Possible interpretation of each PC:
# - PC1: Frequent travelers who own more vehicles.
# - PC2: Older people with small householdsize.
# - PC3: Travelers who takes more time when traveling
# - PC4: Older people with large householdsize.

# %%
pca_pred_train.head(2)
# Out:
#         PC1       PC2       PC3       PC4
# 0  1.870306  0.107272 -0.824864  0.182916
# 1  0.964927 -0.043260 -0.077355  0.543343

# %% [markdown]
# Drop PC5 as PC1 to PC4 together explains more than 90% of the variables.

# %%
pca_pred_train = pca_pred_train.drop('PC5', axis = 1)

# %% [markdown]
# sanity check with linear regression that PC1 - PC4 would be sufficient to explain the dependent variable.

# %%
reg = linear_model.LogisticRegression()
reg.fit(pca_pred_train, train_data['travel_mode'])
print('The estimated coefficients: ', reg.coef_)
print('The estimated intercept (e.g., $\beta_0$): ', reg.intercept_)
print('R^2 for test: %.2f' % reg.score(pca_pred_train, train_data['travel_mode']))
# Out:
# The estimated coefficients:  [[ 0.96639532  0.8831797   1.02343372 -0.00511068]]
# The estimated intercept (e.g., eta_0$):  [1.93156002]
# R^2 for test: 0.84

# %% [markdown]
# Conduct PCA for test data

# %%
pca_pred_test = executePCA(test_data_std)
# Out:
# variance_ratio of each PC: [0.35617, 0.25076, 0.19475, 0.13122, 0.06709]
#     TrvlTime_number       Age indiv_trvl_frequency     HHVeh    HHsize
# PC1        0.009266 -0.017310             0.650959  0.660851  0.373018
# PC2        0.326136  0.737277             0.150936  0.173725 -0.545066
# PC3        0.942204 -0.248020            -0.117407 -0.012340  0.191836
# PC4       -0.016801  0.625971            -0.263940 -0.130839  0.721869
# PC5        0.074286  0.052636             0.685581 -0.718209  0.076582

# %% [markdown]
# Drop PC5 as PC1 to PC4 together explains more than 90% of the variables.

# %%
pca_pred_test = pca_pred_test.drop('PC5', axis = 1)

# %%
reg = linear_model.LogisticRegression()
reg.fit(pca_pred_test, test_data['travel_mode'])
print('The estimated coefficients: ', reg.coef_)
print('The estimated intercept (e.g., $\beta_0$): ', reg.intercept_)
print('R^2 for test: %.2f' % reg.score(pca_pred_test, test_data['travel_mode']))
# Out:
# The estimated coefficients:  [[ 1.02581852  0.67808653  0.24311826 -0.22949893]]
# The estimated intercept (e.g., eta_0$):  [1.77368572]
# R^2 for test: 0.84

# %% [markdown]
# ## 5.3.	MODEL BUILDING AND EVALUATION: IMPLEMENT THE CLUSTERING ALGORITHMS AND EVALUATE THEIR PERFORMANCE. YOU SHOULD REPORT THE ACCURACY AND PRECISION (FOR THE PREDICTION OF CAR MODE) OF EACH MODEL ON THE TEST SET. (5 POINTS)

# %% [markdown]
# ## 5.3.1. K-means

# %% [markdown]
# Given the clustering result varies quite a lot for each run, I conduct each clustering for 40 runs and extract the one with the score (accurary + precision)

# %% [markdown]
# for trial data

# %%
# ignore warnings message
warnings.filterwarnings("ignore")

# Number of runs
n_runs = 40

# Initialize varaiables
best_kmeans = None
best_score = -1 

# Perform K-means multiple times and reserve the one with the highest accuracy
for _ in range(n_runs):
    kmeans = KMeans(n_clusters=2)
    kmeans_train_preds = kmeans.fit_predict(pca_pred_train)
    
    kmeans_accuracy = accuracy_score(train_data['travel_mode'], kmeans_train_preds)
    kmeans_precision = precision_score(train_data['travel_mode'], kmeans_train_preds)
    kmean_total_score =  kmeans_accuracy + kmeans_precision

    if  kmean_total_score > best_score:
        best_score = kmean_total_score
        best_kmeans = kmeans

# Predict with the best K-means model
kmeans_train_preds = best_kmeans.fit_predict(pca_pred_train)

# %% [markdown]
# for test data

# %%
kmeans_test_preds = best_kmeans.fit_predict(pca_pred_test)

# %% [markdown]
# store both results into one dataframe

# %%
kmean_train_df = pd.DataFrame({'y': train_data['travel_mode'],
                               'y_hat' : kmeans_train_preds})
kmean_test_df = pd.DataFrame({'y': test_data['travel_mode'],
                              'y_hat' : kmeans_test_preds}
                              )

# %% [markdown]
# Result - trial

# %%
# Calculate the confusion matrix
confusion_mat = confusion_matrix(kmean_train_df['y'], kmean_train_df['y_hat'])

# Create a heatmap of the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Kmean Confusion Matrix')
plt.show()

# Evaluate K-means
kmeans_accuracy = accuracy_score(train_data['travel_mode'], kmeans_train_preds)
kmeans_precision = precision_score(train_data['travel_mode'], kmeans_train_preds)

print(f"Accuracy: {kmeans_accuracy:.2f}")
print(f"Precision: {kmeans_precision:.2f}")
# Out:
# Accuracy: 0.58
# Precision: 0.84

# %% [markdown]
# Result - test

# %%
# Calculate the confusion matrix
confusion_mat = confusion_matrix(kmean_test_df['y'], kmean_test_df['y_hat'])

# Create a heatmap of the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Kmean Confusion Matrix')
plt.show()

# Evaluate K-means
kmeans_accuracy = accuracy_score(test_data['travel_mode'], kmeans_test_preds)
kmeans_precision = precision_score(test_data['travel_mode'], kmeans_test_preds)

print(f"Accuracy: {kmeans_accuracy:.2f}")
print(f"Precision: {kmeans_precision:.2f}")
# Out:
# Accuracy: 0.45
# Precision: 0.71

# %% [markdown]
# ## 5.3.2. Gaussian Mixture

# %% [markdown]
# Given the clustering result varies quite a lot for each run, I conduct each clustering for 40 runs and extract the one with the best accuracy.

# %% [markdown]
# for trial data

# %%
# Initialize varaiables
best_gmm = None
best_score = -1 

# Perform K-means multiple times and reserve the one with the highest accuracy
for _ in range(n_runs):
    gmm = GaussianMixture(n_components=2)
    gmm_train_preds = gmm.fit_predict(pca_pred_train)
    
    gmm_accuracy = accuracy_score(train_data['travel_mode'], gmm_train_preds)
    gmm_precision = precision_score(train_data['travel_mode'], kmeans_train_preds)
    gmm_total_score =  gmm_accuracy + gmm_precision
    
    if  gmm_total_score > best_score:
        best_score = gmm_total_score
        best_gmm = gmm

# Predict with the best K-means model
gmm_train_preds = best_gmm.fit_predict(pca_pred_train)

# %% [markdown]
# for test data

# %%
gmm_test_preds = best_gmm.fit_predict(pca_pred_test)

# %%
gmm_train_df = pd.DataFrame({'y': train_data['travel_mode'],
                             'y_hat' : gmm_train_preds})
gmm_test_df = pd.DataFrame({'y': test_data['travel_mode'],
                            'y_hat' : gmm_test_preds})

# %% [markdown]
# Result - trial

# %%
# Calculate the confusion matrix
confusion_mat = confusion_matrix(gmm_train_df['y'], gmm_train_df['y_hat'])

# Create a heatmap of the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Gaussian Mixture Confusion Matrix')
plt.show

# Evaluate K-means
gmm_accuracy = accuracy_score(train_data['travel_mode'], gmm_train_preds)
gmm_precision = precision_score(train_data['travel_mode'], gmm_train_preds)

print(f"Accuracy: {gmm_accuracy:.2f}")
print(f"Precision: {gmm_precision:.2f}")
# Out:
# Accuracy: 0.57
# Precision: 0.76

# %% [markdown]
# Result -test

# %%
# Calculate the confusion matrix
confusion_mat = confusion_matrix(gmm_test_df['y'], gmm_test_df['y_hat'])

# Create a heatmap of the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Gaussian Mixture Confusion Matrix')
plt.show()

# Evaluate K-means
gmm_accuracy = accuracy_score(test_data['travel_mode'], gmm_test_preds)
gmm_precision = precision_score(test_data['travel_mode'], gmm_test_preds)

print(f"Accuracy: {gmm_accuracy:.2f}")
print(f"Precision: {gmm_precision:.2f}")
# Out:
# Accuracy: 0.66
# Precision: 0.76
